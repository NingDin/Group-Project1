# %%
import tweepy
import config
from pprint import pprint

# %%
client=tweepy.Client(bearer_token=config.BEARER_TOKEN)

# %%
dir(client)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_construct_response',
#  '_get_authenticating_user_id',
#  '_get_oauth_1_authenticating_user_id',
#  '_get_oauth_2_authenticating_user_id',
#  '_make_request',
#  '_process_data',
#  '_process_includes',
#  '_process_params',
#  'access_token',
#  'access_token_secret',
#  'add_list_member',
#  'bearer_token',
#  'block',
#  'bookmark',
#  'consumer_key',
#  'consumer_secret',
#  'create_compliance_job',
#  'create_direct_message',
#  'create_direct_message_conversation',
#  'create_dm',
#  'create_dm_conversation',
#  'create_list',
#  'create_tweet',
#  'delete_list',
#  'delete_tweet',
#  'follow',
#  'follow_list',
#  'follow_user',
#  'get_all_tweets_count',
#  'get_blocked',
#  'get_bookmarks',
#  'get_compliance_job',
#  'get_compliance_jobs',
#  'get_direct_message_events',
#  'get_dm_events',
#  'get_followed_lists',
#  'get_home_timeline',
#  'get_liked_tweets',
#  'get_liking_users',
#  'get_list',
#  'get_list_followers',
#  'get_list_members',
#  'get_list_memberships',
#  'get_list_tweets',
#  'get_me',
#  'get_muted',
#  'get_owned_lists',
#  'get_pinned_lists',
#  'get_quote_tweets',
#  'get_recent_tweets_count',
#  'get_retweeters',
#  'get_space',
#  'get_space_buyers',
#  'get_space_tweets',
#  'get_spaces',
#  'get_tweet',
#  'get_tweets',
#  'get_user',
#  'get_users',
#  'get_users_followers',
#  'get_users_following',
#  'get_users_mentions',
#  'get_users_tweets',
#  'hide_reply',
#  'like',
#  'mute',
#  'pin_list',
#  'remove_bookmark',
#  'remove_list_member',
#  'request',
#  'return_type',
#  'retweet',
#  'search_all_tweets',
#  'search_recent_tweets',
#  'search_spaces',
#  'session',
#  'unblock',
#  'unfollow',
#  'unfollow_list',
#  'unfollow_user',
#  'unhide_reply',
#  'unlike',
#  'unmute',
#  'unpin_list',
#  'unretweet',
#  'update_list',
#  'user_agent',
#  'wait_on_rate_limit']

# %%
for user in client.get_users
    print(user)
# Out:
#   Input In [49]
#     for user in client.get_users
#                                 ^
# SyntaxError: invalid syntax

# %%
query='option trading -has:media'
response=client.search_recent_tweets(query=query,max_results=100,tweet_fields=['created_at','lang'],\
                                     expansions=['author_id'],user_fields=['profile_image_url'])
pprint(response)
# Out:
# Response(data=[<Tweet id=1600183481602301952 text='RT @Mohinibanknifty: @missNifty2138 @IamRaviTejaG @sanjaysmitasidd Stock trading karo, future options moh maya he.. \nFuture lene baad, tuma…'>, <Tweet id=1600181441350205440 text='RT @OptionInversion: @Abhishekkar_ Start with small capital say Rs.10000.\nTry to learn as much concepts of Option Trading as possible using…'>, <Tweet id=1600181425075937281 text='@barnyboatman Radio on a real radio (not a streamed one) is live.I use this option in conjunction with the TV when trading on Irish sport.'>, <Tweet id=1600180749499789314 text='$DBL - DBL: Slight Premium Despite Volatility, Another Potential Option. https://t.co/EjDuBnpxB8 #stocks #trading #business'>, <Tweet id=1600180140423581696 text='@joe_werrick @Brandon_Warne Understand the pitching aspect but I’d rather use a package like this to find a stable option at catcher based on what I’ve seen from rumors about blue jays trading one of their young guys. I think brooks doesn’t stick here if we do sign a SS.'>, <Tweet id=1600179064966242308 text='@DbacksStatsInfo Dbacks aren’t trading McCarthy (under control until 
# sheedhu130
# https://pbs.twimg.com/profile_images/1586586408554496000/ptQUlof__normal.jpg
# 1600163669371154433
# 3mit_patel
# https://pbs.twimg.com/profile_images/1583449797625012225/if6-KHiQ_normal.jpg
# 1600162781919326209
# belranjan
# https://pbs.twimg.com/profile_images/834839768403935241/hfjxNUpu_normal.jpg
# 1600162717553549314
# mpchamp01
# https://pbs.twimg.com/profile_images/1562498067894763521/0W0F27HF_normal.jpg
# 1600162607754727427
# BhaskarMazumd13
# https://pbs.twimg.com/profile_images/1600164147634659328/oJI3J2J2_normal.jpg
# 1600160625874698240
# RespectWallSt
# https://pbs.twimg.com/profile_images/1480218647285035008/zkmZWDox_normal.png
# 1600159920011509760
# Chawkz1215
# https://pbs.twimg.com/profile_images/1432810996326797315/tSfN6pMg_normal.jpg
# 1600159747595960322
# hiroyuk37368699
# https://pbs.twimg.com/profile_images/1456795773929410561/D9keCO27_normal.jpg
# 1600159194463674374
# gupta123654789
# https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png
# 1600159079921393664
# iananomous19
# https://pbs.twimg.com/profile_images/1599434876758867969/UyIus88C_normal.jpg
# 1600158595446108160
# KalyanaramanSi1
# https://pbs.twimg.com/profile_images/1379243906139713537/sX1g8iCX_normal.jpg
# 1600157499327655937
# Debasis98364167
# https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png
# 1600154883478282241
# wiseman57741006
# https://pbs.twimg.com/profile_images/1594994378765991938/fIuPM8ZE_normal.png
# 1600154858744840197
# YMehta_
# https://pbs.twimg.com/profile_images/1559469257557061632/QJM2iR7W_normal.jpg
# 1600154829665366016
# MASTERFL3X05
# https://pbs.twimg.com/profile_images/1539267183678631938/CGixuSkY_normal.jpg
# 1600154615445860360
# stock26583922
# https://pbs.twimg.com/profile_images/1570389100821360641/78y0KKlS_normal.jpg
# 1600154431462440962
# OptionAlarm
# https://pbs.twimg.com/profile_images/1187990974/OA_Logo_Twitter_normal.jpg
# 1600152931541868544
# ManojShinde01
# https://pbs.twimg.com/profile_images/1506816224813977604/vSJtIwrp_normal.jpg

# %%
for tweet in tweepy.paginator(client.search_recent_tweets,query=query,max_results=100).flatten(limit=500):
    print(tweet.id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 for tweet in tweepy.paginator(client.search_recent_tweets,query=query,max_results=100).flatten(limit=500):
#       2     print(tweet.id)
#
# AttributeError: module 'tweepy' has no attribute 'paginator'

# %%
file_name='tweets.txt'
#a plus append into the same file
with opne(file_name,'a+') as filehandler:
for tweet in tweepy.paginator(client.search_recent_tweets,query=query,max_results=100).flatten(limit=500):
    print(tweet.id)
    filehandler.write('%s\n' %tweet.id) # note %s\n it wrtie one line at the time
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [34], in <cell line: 1>()
# ----> 1 for tweet in tweepy.paginator(client.search_recent_tweets,query=query,max_results=100).flatten(limit=500):
#       2     print(tweet.id)
#
# AttributeError: module 'tweepy' has no attribute 'paginator'

# %%
# need academic access
query='short trading strategy'
start_time='2020-01-01T00:00:00Z'
end_time='2020-05-01-01T00:00:00Z'
response=client.search_all_tweets(query=query,max_results=100,start_time=start_time,end_time=end_time)
for tweet in response.data: # do not forgot .data
    print(tweet.id)
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Input In [36], in <cell line: 4>()
#       2 start_time='2020-01-01T00:00:00Z'
#       3 end_time='2020-05-01-01T00:00:00Z'
# ----> 4 response=client.search_all_tweets(query=query,max_results=100,start_time=start_time,end_time=end_time)
#       5 for tweet in response.data: # do not forgot .data
#       6     print(tweet.id)
#
# File D:\ANACODA\lib\site-packages\tweepy\client.py:1163, in Client.search_all_tweets(self, query, **params)
#    1071 """search_all_tweets( \
#    1072     query, *, end_time=None, expansions=None, max_results=None, \
#    1073     media_fields=None, next_token=None, place_fields=None, \
#    (...)
#    1160 .. _pagination: https://developer.twitter.com/en/docs/twitter-api/tweets/search/integrate/paginate
#    1161 """
#    1162 params["query"] = query
# -> 1163 return self._make_request(
#    1164     "GET", "/2/tweets/search/all", params=params,
#    1165     endpoint_parameters=(
#    1166         "end_time", "expansions", "max_results", "media.fields",
#    1167         "next_token", "place.fields", "poll.fields", "query",
#    1168         "since_id", "sort_order", "start_time", "tweet.fields",
#    1169         "until_id", "user.fields"
#    1170     ), data_type=Tweet
#    1171 )
#
# File D:\ANACODA\lib\site-packages\tweepy\client.py:129, in BaseClient._make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     123 def _make_request(
#     124     self, method, route, params={}, endpoint_parameters=(), json=None,
#     125     data_type=None, user_auth=False
#     126 ):
#     127     request_params = self._process_params(params, endpoint_parameters)
# --> 129     response = self.request(method, route, params=request_params,
#     130                             json=json, user_auth=user_auth)
#     132     if self.return_type is requests.Response:
#     133         return response
#
# File D:\ANACODA\lib\site-packages\tweepy\client.py:100, in BaseClient.request(self, method, route, params, json, user_auth)
#      98     raise Unauthorized(response)
#      99 if response.status_code == 403:
# --> 100     raise Forbidden(response)
#     101 if response.status_code == 404:
#     102     raise NotFound(response)
#
# Forbidden: 403 Forbidden
# When authenticating requests to the Twitter API v2 endpoints, you must use keys and tokens from a Twitter developer App that is attached to a Project. You can create a project via the developer portal.

# %%
# recent count 
counts=client.get_recent_tweets_count(query=query,granularity='day')
for count in counts.data:
    print(count)
# Out:
# {'end': '2022-11-30T00:00:00.000Z', 'start': '2022-11-29T17:39:13.000Z', 'tweet_count': 8}
# {'end': '2022-12-01T00:00:00.000Z', 'start': '2022-11-30T00:00:00.000Z', 'tweet_count': 57}
# {'end': '2022-12-02T00:00:00.000Z', 'start': '2022-12-01T00:00:00.000Z', 'tweet_count': 56}
# {'end': '2022-12-03T00:00:00.000Z', 'start': '2022-12-02T00:00:00.000Z', 'tweet_count': 36}
# {'end': '2022-12-04T00:00:00.000Z', 'start': '2022-12-03T00:00:00.000Z', 'tweet_count': 47}
# {'end': '2022-12-05T00:00:00.000Z', 'start': '2022-12-04T00:00:00.000Z', 'tweet_count': 46}
# {'end': '2022-12-06T00:00:00.000Z', 'start': '2022-12-05T00:00:00.000Z', 'tweet_count': 65}
# {'end': '2022-12-06T17:39:13.000Z', 'start': '2022-12-06T00:00:00.000Z', 'tweet_count': 47}

# %%
# recent count 
counts=client.get_recent_tweets_count(query=query,granularity='day')
for count in counts.data:
    print(count)

# %%
users={u['id']:u for u in response.includes['users']}
for tweet in response.data:
    if users[tweet.author_id]:
        user=users[tweet.author_id]
        print(tweet.id)
        print(user.username)
        print(user.profile_image_url)

# %%
client.get_

# %%
user=client.get_uers_followers(id=config.USER_ID)
for user in user.data:
    print(user)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 client.get_uers_followers(id=config.USER_ID)
#
# AttributeError: 'Client' object has no attribute 'get_uers_followers'
