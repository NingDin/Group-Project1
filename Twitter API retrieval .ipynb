# %%
import requests
import pandas as pd
from pprint import pprint
import json
import time
import datetime
# !pip install tweepy

# from twitter_api_key import api_key
# Out:
# Requirement already satisfied: tweepy in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (4.12.1)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from tweepy) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\david\anaconda3\envs\pythondata\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.4)

# %%
import tweepy

bearer_token = "AAAAAAAAAAAAAAAAAAAAAPpkkAEAAAAAKL39DCq6ZPFGvgdMWHeogkMC%2FCY%3DHFILgAyE2UpPxfiiufeIva5NX8iBHMZRPDlSuLqJDO6IKJurPH"

consumer_key = "MTOpic1RalD9RgiNfsV1dGqCM"
consumer_secret = "KmQeL9yTPiKqTDZXZOaNNxpXf2MkgMh8MPjSFrvsevNRNdjfiV"

access_token = "1443048757721972737-V2hzF2tpVQDFf6mjYBqiwSn7fESXxN"
access_token_secret = "nZZ3Kc1WaspnnlCruBwDjoKp3GjD1YT6fhkCnIPEo19bY"

client = tweepy.Client(bearer_token=bearer_token)

# %%
client

# %%
# Get User's Followers

# This endpoint/method returns a list of users who are followers of the
# specified user ID

user_id = 1061098849962471424
nings_follows =[]
# By default, only the ID, name, and username fields of each user will be
# returned
# Additional fields can be retrieved using the user_fields parameter
response = client.get_users_following(
    user_id, user_fields=["profile_image_url"]
)

# for user in response.data:
#     print(user.username, user.profile_image_url)
#     print(user)
    
    
# By default, this endpoint/method returns 100 results
# You can retrieve up to 1000 users by specifying max_results
response = client.get_users_following(user_id, max_results=1000)
for user in response:
    print(user)
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28216\2939567298.py in <module>
#      10 # Additional fields can be retrieved using the user_fields parameter
#      11 response = client.get_users_following(
# ---> 12     user_id, user_fields=["profile_image_url"]
#      13 )
#      14
#
# ~\anaconda3\envs\PythonData\lib\site-packages\tweepy\client.py in get_users_following(self, id, user_auth, **params)
#    2150                 "expansions", "max_results", "pagination_token",
#    2151                 "tweet.fields", "user.fields"
# -> 2152             ), data_type=User, user_auth=user_auth
#    2153         )
#    2154
#
# ~\anaconda3\envs\PythonData\lib\site-packages\tweepy\client.py in _make_request(self, method, route, params, endpoint_parameters, json, data_type, user_auth)
#     128
#     129         response = self.request(method, route, params=request_params,
# --> 130                                 json=json, user_auth=user_auth)
#     131
#     132         if self.return_type is requests.Response:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\tweepy\client.py in request(self, method, route, params, json, user_auth)
#     113                     return self.request(method, route, params, json, user_auth)
#     114                 else:
# --> 115                     raise TooManyRequests(response)
#     116             if response.status_code >= 500:
#     117                 raise TwitterServerError(response)
#
# TooManyRequests: 429 Too Many Requests
# Too Many Requests

# %%
response = client.get_users_following(user_id, max_results=1000)
for user in response:
    print(user)
    time.sleep(5)
# Out:
# [<User id=1443048757721972737 name=David username=DavidScienceCom>, <User id=20972371 name=Dan Carlin username=HardcoreHistory>, <User id=13334762 name=GitHub username=github>, <User id=878268519032532992 name=Max Bulenda username=maxbulenda>, <User id=1491138793163870213 name=Strategas Asset Management username=strategasasset>, <User id=1535311072181231617 name=Compounding Quality username=QCompounding>, <User id=1503117418071220230 name=Macro EU & US (previously investor743) username=MacroEu>, <User id=1405268733489303557 name=Passant H username=P12328197359>, <User id=4747641663 name=AGF username=agf>, <User id=108021761 name=ValueWalk - Exclusive hedge fund info (below) username=valuewalk>, <User id=245581702 name=Wes Gray 🇺🇸 username=alphaarchitect>, <User id=321372866 name=steven blitz username=sblitz1>, <User id=778186350 name=Mikael Sarwe username=MikaelSarwe>, <User id=1467804779690692608 name=Carl Hodson-Thomas 🇺🇦 username=PrometheusCHT>, <User id=1301910697 name=Vanda Research username=vandaresearch>, <User id=2313837474 name=Ned Davis Research username=NDR_Research>, <User id=206366801 name=Farah ElBahrawy username=farahesque>, <User id=1335944061774155777 name=Absolute Return Partners username=AbsoluteReturnP>, <User id=3236381990 name=Bloomberg Terminal username=TheTerminal>, <User id=1199145208895725573 name=Stat Arb username=quant_arb>, <User id=1200359005 name=Richard Yetsenga 叶森 🇦🇺 🇭🇰 🇹🇭 🇳🇱 username=ricyet>, <User id=1248962047867576321 name=International Institute of Finance and Accounting username=Interna26692915>, <User id=497266110 name=Strategas username=StrategasRP>, <User id=895213223724666880 name=Dr. Dominic Royé @dr_xeo@mstdn.social username=dr_xeo>, <User id=1248579691415351296 name=Global_Macro username=Marcomadness2>, <User id=1246136668014301184 name=App Economy Insights username=EconomyApp>, <User id=1948928522 name=Michael Msika username=mikamsika>, <User id=2991672322 name=🏳️‍🌈 Patrick Krizan 🇺🇦 username=PatrickKrizan>, <User id=22073146 name=Mike Zaccardi, CFA, CMT username=MikeZaccardi>, <User id=182910373 name=Ron Butler username=ronmortgageguy>, <User id=46804450 name=ChicagoFed username=ChicagoFed>, <User id=57333256 name=Michael Ashton username=inflation_guy>, <User id=143477156 name=Dallas Fed username=DallasFed>, <User id=12061032 name=Rui Ma 马睿 username=ruima>, <User id=380993093 name=Marc Rubinstein username=MarcRuby>, <User id=17239967 name=ClevelandFedResearch username=ClevFedResearch>, <User id=425134513 name=Richmond Fed Research username=RichFedResearch>, <User id=15072071 name=New York Fed username=NewYorkFed>, <User id=5402612 name=BBC Breaking News username=BBCBreaking>, <User id=48001143 name=Phila Fed Research username=PhilFedResearch>, <User id=120176950 name=Treasury Department username=USTreasury>, <User id=246621297 name=George Gammon username=GeorgeGammon>, <User id=1238572372954767360 name=Layoffs.fyi username=Layoffsfyi>, <User id=340387261 name=Gavin Baker username=GavinSBaker>, <User id=775175696645623808 name=Anas Alhajji username=anasalhajji>, <User id=1688796138 name=Peter Zeihan username=PeterZeihan>, <User id=1016854943087710208 name=Bison Interests username=BisonInterests>, <User id=989912836901089282 name=Blockworks username=Blockworks_>, <User id=1364226660 name=Jawad Mian username=jsmian>, <User id=2323253005 name=Lyall Taylor username=LT3000Lyall>, <User id=44127350 name=Paul Hodges username=paulhodges1>, <User id=1540344422939983874 name=Forward Guidance username=ForwardGuidance>, <User id=91704576 name=Vincent Deluard username=VincentDeluard>, <User id=1374003455195545601 name=Darius Dale username=42macroDDale>, <User id=1453373812939141130 name=Calderwood Capital username=calderwoodcap>, <User id=1343646616566292482 name=KEDM.com username=KEDM_COM>, <User id=587074680 name=Jens Nordvig 🇩🇰🇺🇸🇺🇦 username=jnordvig>, <User id=784233687487393792 name=𝐏𝐢𝐧𝐞𝐜𝐨𝐧𝐞 𝐌𝐚𝐜𝐫𝐨 username=pineconemacro>, <User id=220016580 name=fred hickey username=htsfhickey>, <User id=3 ...
# {}
# []
# {'result_count': 895}

# %%
type(response)
# Out:
# tweepy.client.Response

# %%
response.data[0]
# Out:
# <User id=1443048757721972737 name=David username=DavidScienceCom>

# %%
print(nings_follows)
# Out:
# [<User id=1443048757721972737 name=David username=DavidScienceCom>, <User id=20972371 name=Dan Carlin username=HardcoreHistory>, <User id=13334762 name=GitHub username=github>, <User id=878268519032532992 name=Max Bulenda username=maxbulenda>, <User id=1491138793163870213 name=Strategas Asset Management username=strategasasset>, <User id=1535311072181231617 name=Compounding Quality username=QCompounding>, <User id=1503117418071220230 name=Macro EU & US (previously investor743) username=MacroEu>, <User id=1405268733489303557 name=Passant H username=P12328197359>, <User id=4747641663 name=AGF username=agf>, <User id=108021761 name=ValueWalk - Exclusive hedge fund info (below) username=valuewalk>, <User id=245581702 name=Wes Gray 🇺🇸 username=alphaarchitect>, <User id=321372866 name=steven blitz username=sblitz1>, <User id=778186350 name=Mikael Sarwe username=MikaelSarwe>, <User id=1467804779690692608 name=Carl Hodson-Thomas 🇺🇦 username=PrometheusCHT>, <User id=1301910697 name=Vanda Research username=vandaresearch>, <User id=2313837474 name=Ned Davis Research username=NDR_Research>, <User id=206366801 name=Farah ElBahrawy username=farahesque>, <User id=1335944061774155777 name=Absolute Return Partners username=AbsoluteReturnP>, <User id=3236381990 name=Bloomberg Terminal username=TheTerminal>, <User id=1199145208895725573 name=Stat Arb username=quant_arb>, <User id=1200359005 name=Richard Yetsenga 叶森 🇦🇺 🇭🇰 🇹🇭 🇳🇱 username=ricyet>, <User id=1248962047867576321 name=International Institute of Finance and Accounting username=Interna26692915>, <User id=497266110 name=Strategas username=StrategasRP>, <User id=895213223724666880 name=Dr. Dominic Royé @dr_xeo@mstdn.social username=dr_xeo>, <User id=1248579691415351296 name=Global_Macro username=Marcomadness2>, <User id=1246136668014301184 name=App Economy Insights username=EconomyApp>, <User id=1948928522 name=Michael Msika username=mikamsika>, <User id=2991672322 name=🏳️‍🌈 Patrick Krizan 🇺🇦 username=PatrickKrizan>, <User id=22073146 name=Mike Zaccardi, CFA, CMT username=MikeZaccardi>, <User id=182910373 name=Ron Butler username=ronmortgageguy>, <User id=46804450 name=ChicagoFed username=ChicagoFed>, <User id=57333256 name=Michael Ashton username=inflation_guy>, <User id=143477156 name=Dallas Fed username=DallasFed>, <User id=12061032 name=Rui Ma 马睿 username=ruima>, <User id=380993093 name=Marc Rubinstein username=MarcRuby>, <User id=17239967 name=ClevelandFedResearch username=ClevFedResearch>, <User id=425134513 name=Richmond Fed Research username=RichFedResearch>, <User id=15072071 name=New York Fed username=NewYorkFed>, <User id=5402612 name=BBC Breaking News username=BBCBreaking>, <User id=48001143 name=Phila Fed Research username=PhilFedResearch>, <User id=120176950 name=Treasury Department username=USTreasury>, <User id=246621297 name=George Gammon username=GeorgeGammon>, <User id=1238572372954767360 name=Layoffs.fyi username=Layoffsfyi>, <User id=340387261 name=Gavin Baker username=GavinSBaker>, <User id=775175696645623808 name=Anas Alhajji username=anasalhajji>, <User id=1688796138 name=Peter Zeihan username=PeterZeihan>, <User id=1016854943087710208 name=Bison Interests username=BisonInterests>, <User id=989912836901089282 name=Blockworks username=Blockworks_>, <User id=1364226660 name=Jawad Mian username=jsmian>, <User id=2323253005 name=Lyall Taylor username=LT3000Lyall>, <User id=44127350 name=Paul Hodges username=paulhodges1>, <User id=1540344422939983874 name=Forward Guidance username=ForwardGuidance>, <User id=91704576 name=Vincent Deluard username=VincentDeluard>, <User id=1374003455195545601 name=Darius Dale username=42macroDDale>, <User id=1453373812939141130 name=Calderwood Capital username=calderwoodcap>, <User id=1343646616566292482 name=KEDM.com username=KEDM_COM>, <User id=587074680 name=Jens Nordvig 🇩🇰🇺🇸🇺🇦 username=jnordvig>, <User id=784233687487393792 name=𝐏𝐢𝐧𝐞𝐜𝐨𝐧𝐞 𝐌𝐚𝐜𝐫𝐨 username=pineconemacro>, <User id=220016580 name=fred hickey username=htsfhickey>, <User id=3 ...

# %%
response = client.get_users_following(user_id, max_results=1000)

# %%
dict(response[0][0])
# Out:
# {'id': 1443048757721972737, 'name': 'David', 'username': 'DavidScienceCom'}

# %%
columns = set()
users = []
usersnames = []
twitter_id = []
twitter_name =[]
for x in range(895):
    print(response[0][x])
    users.append(dict(response[0][x]))
    usersnames.append(response[0][x]["username"])
    twitter_id.append(response[0][x]["id"])
    twitter_name.append(response[0][x]["name"])
    keys = dict(response[0][x]).keys()
    for k in keys:
        columns.add(k)
# Out:
# DavidScienceCom
# HardcoreHistory
# github
# maxbulenda
# strategasasset
# QCompounding
# MacroEu
# P12328197359
# agf
# valuewalk
# alphaarchitect
# sblitz1
# MikaelSarwe
# PrometheusCHT
# vandaresearch
# NDR_Research
# farahesque
# AbsoluteReturnP
# TheTerminal
# quant_arb
# ricyet
# Interna26692915
# StrategasRP
# dr_xeo
# Marcomadness2
# EconomyApp
# mikamsika
# PatrickKrizan
# MikeZaccardi
# ronmortgageguy
# ChicagoFed
# inflation_guy
# DallasFed
# ruima
# MarcRuby
# ClevFedResearch
# RichFedResearch
# NewYorkFed
# BBCBreaking
# PhilFedResearch
# USTreasury
# GeorgeGammon
# Layoffsfyi
# GavinSBaker
# anasalhajji
# PeterZeihan
# BisonInterests
# Blockworks_
# jsmian
# LT3000Lyall
# paulhodges1
# ForwardGuidance
# VincentDeluard
# 42macroDDale
# calderwoodcap
# KEDM_COM
# jnordvig
# pineconemacro
# htsfhickey
# LONGCONVEXITY
# FedGuy12
# hussmanjp
# hendry_hugh
# contrarian8888
# spomboy
# agnostoxxx
# WallStCynic
# dailydirtnap
# UrbanKaoboy
# TaviCosta
# MichaelKantro
# EconguyRosie
# Josh_Young_1
# ttmygh
# AndreasSteno
# hkuppy
# VrntPerception
# Calamos
# ThriftyJake
# eriksen_tim
# leavenpartners
# jasonfurman
# DegenSpartan
# BTA_Binary_Tree
# dailychartbook
# MrBlonde_macro
# fisherinvest
# GregDaco
# RetirementRight
# KobeissiLetter
# PantheonMacro
# babakmolavi
# RichardDias_CFA
# AaronKennon
# SagaPartners
# BittelJulien
# TechTraderView
# LarryCheungCFA
# MacroCharts
# Fidelity
# SenateStock
# S3Partners
# OptionAlpha
# EIAgov
# HarvardGrwthLab
# macro_daily
# PPGMacro
# mintzmyer
# Cher1991la
# MacroAlf
# VIXandMore
# EPBResearch
# uclaanderson
# UCLA
# wiley_finance
# dampedspring
# t1alpha
# DailyTradeAlert
# SoberLook
# GlobalXETFs
# macrocephalopod
# JessicaNutt96
# StockWonk
# Kinfo
# Dividends123
# TDAM_Canada
# SamRo
# SumZero
# Davidwoounbound
# REITs_Nareit
# mitsloanexperts
# ClearHarborAM
# CapitalVoss
# ism
# Alpha_Ex_LLC
# mercer
# SPGMarketIntel
# cheaperthanguru
# CongressAsset
# DanielSLoeb1
# fdestin
# PIMCO
# AllianzGI_view
# LokkenInvest
# CommonwealthFN
# abnormalreturns
# mjmauboussin
# FulcrumAsset
# Ksidiii
# JulianMI2
# DNB_Bank
# super_trades
# SSalim0002
# BlogJulianKomar
# ManningNapier
# Russell_Invest
# ThornburgFunds
# TeCLaro
# TheCaprockGroup
# FolioDx
# SofiaHCBBG
# bigmagicdao
# tesuta001
# RonStoeferle
# nicolawealth
# TrueTraderNet
# danielcrosby
# LkTahoeBadger
# HFAlert
# mikepsilva
# SinclairEuan
# FadingRallies
# VJDementia
# kellogg
# Andover
# jam_croissant
# SqueezeMetrics
# breakingmkts
# acrossthespread
# ChrisCamillo
# racernic
# wintonARK
# AlmanacTrader
# lincolnsamelson
# CoatTrader
# T_Money610
# Protalix_Bio
# omahacharts
# InvestReSolve
# cissan_9984
# ronbertino
# BpTfeed
# EricBalchunas
# LoneCapital
# TCMLLC
# marcuslemonis
# themarketear
# yuriymatso
# SVMAsset
# MikiHughes166
# FuturesBen_TDAN
# ScottConnor_TDA
# chicagosean
# paulwimmers
# SelfBrian
# IGcom
# ____3rd____
# Glencore
# ycinar
# Nationwide
# GregCapra
# ascphoto
# TradersExpo
# olvelez007
# carlquintanilla
# tastytraderMike
# tastytrade
# ball8281
# TashaARK
# ARKInvest
# RitholtzWealth
# mwebster1971
# CarterBWorth
# CathieDWood
# PerfectlyHedged
# AlphaJason
# AB_insights
# elkwood66
# ppearlman
# Benzinga
# mikecammarata
# JasonRaznick
# EBoboch
# SubhadipNandy16
# Guruleaks1
# followtheh
# kathylienfx
# Trader_mcaruso
# AmCapTrader
# T3TradingGroup
# WarrenBuffett
# StockAvenue
# marcchaikin
# EdwardOThorp
# longtailalpha
# MebFaber
# EddyElfenbein
# dragonfly_xyz
# PeterSchiff
# AnalyticChicago
# StocktonKatie
# spotgamma
# zerohedge
# 1nvestor
# ScottTheCowGuy
# WingGirlTrader
# tradewithjoe
# DayTradeWarrior
# Live_Traders
# theemptyrobot
# TripleDTrader
# TrueTradingGrp
# MikeEdward_TTG
# EquitiesPlayer
# 77STPaco
# garlandrg
# eWhispers
# BeingHorizontal
# OddStockTrader
# tradesbychris
# 6_Figure_Invest
# Th_Krauss
# VixCentral
# BogeyBoiBrandon
# qayyumrajan
# LJKawa
# MazzaDave
# BullandBaird
# theandrewhsmith
# cer_hedge
# J_B_Horne
# tracyalloway
# RichardERoeper
# C21Investments
# CB1Cap
# 361Capital
# todd_harrison
# ag_trader
# VicNiederhoffer
# jposhaughnessy
# MichaelGLamothe
# bespokeinvest
# Schwab4RIAs
# jasonzweigwsj
# TheMarketHuddle
# kevinmuir
# Dean_Devlin
# SteveSosnick
# BlackBoxStocks
# priceinaction
# rjparkerjr09
# thechartist
# IBD_JNielsen
# IBD_CGessel
# IBD_KShreve
# AlissaCoram
# mb_willoughby
# OMillionaires
# OptionsMike
# TradingThomas3
# michaelbatnick
# morganhousel
# patrick_oshag
# SuperMugatu
# CiovaccoCapital
# FundFanatic
# Jattitude73
# JBoyd_TDA
# Chris_Mischler
# LynAldenContact
# Covel
# basso_tom
# conservmillen
# LizClaman
# RatPackTrader
# VickiLeeDillard
# AngelicaAmarand
# d1rtydan
# EdBorgato
# SiteGround
# UpslopeCapital
# east_cap
# whalewisdom
# mochitown
# CaseysCharts
# profplum99
# ErikSTownsend
# LeitnerJim
# Macro_Hive
# countstep1
# SantiagoAuFund
# michaellebowitz
# FortifiedEnter1
# Aman__Deep
# chigrl
# HulkCapital
# elementmacro
# barronsonline
# Nivallia
# awealthofcs
# VolatilityQ
# bennpeifert
# GestaltU
# ReformedTrader
# coiledspringcap
# trent_d_legacy
# Shorteverythin1
# anthony113742
# FedProm
# hmeisler
# kaneinthename
# TradeWithDoug
# prchovanec
# RobinWigg
# sidprabhu
# michaelbkrause
# stevekavdc
# 60Minutes
# youyanggu
# SystematiCK_
# jackschwager
# Randy_Watts_
# LeifSoreide
# williamoneilco
# TradingHaven
# TicTocTick
# JamesFournier
# AlinPuian
# DeItaone
# Gold_Mansack
# hedgopia
# Forbes
# clair520
# TplusTwoHolding
# Jimmyjude13
# davidsettle42
# pearkes
# Jesse_Livermore
# blueorcainvest
# PatrickWalker56
# berthon_jones
# realwillmeade
# AdamMancini4
# TgMacro
# iancassel
# TommyThornton
# Trader_Dante
# G_krupins
# cfromhertz
# ivanhoff2
# AngieMiles
# ShortVixTrade
# sm_sears
# BGR
# mikethebbop
# modestproposal1
# psk2329
# MadMraket
# CreditSuisse
# jpmorgan
# MorganStanley
# MerrillLynch
# RobinBrooksIIF
# sarahfrier
# Joanne_AdaptIQ
# AlexZukin
# HalMarshall2309
# JamesGRickards
# HedgeyeIndstrls
# HedgeyeComm
# ReutersCommods
# Reuters
# ronbousso1
# ReutersPR
# Jennifer_Hiller
# JavierBlas
# IHSMarkit
# twilio
# RobertMaguire_
# juthica
# ExpertInst
# ogfz_
# TommmyF
# Jakubstadt
# TheChartReport
# joe_shipman
# Hedgeye
# JeffSnider_AIP
# CaitlinLong_
# DigitalDonF
# MarkYusko
# Fitzstock2004
# andrewnyquist
# MstarBenJohnson
# TomWhite_TDAN
# southernmacro
# Wolf_Dreams7
# DreamWasArtist
# RajMahalTweets
# lexvandam
# WSJecon
# trmcdonald
# steveliesman
# Invest420
# BeckyQuick
# GuyAdami
# RiskReversal
# timseymour
# MarketCurrents
# MthuliNcube
# steve_hanke
# JBMackenzie_TDA
# BenWatson_TDA
# ScottMinerd
# _BurtWhite
# Anthony_Valeri
# LPL
# cullenroche
# Stephanie_Link
# matt_levine
# dollarsanddata
# skorusARK
# agurevich23
# CGasparino
# SvenCarlin
# GunjanJS
# Bob_Iaccino
# AndrewPancholi
# JudyKShaw
# FadeTheXX
# Upticken
# Fxhedgers
# calculatedrisk
# jfahmy
# ITPM_com
# AntonKreil
# GregoireDup
# Chris_Quill
# Carl_C_Icahn
# BillAckman
# EmpireResearch
# WhitneyTilson
# iw_inst
# Michael_Khouw
# amazonmusic
# OptionsAction
# PatrickEBoyle
# VolatilityVIX
# PianoAround
# investinvol
# JermalChandler
# kpdavitt13
# ScottGottliebMD
# JoeTigay
# vxx46
# Djd551
# assettv
# swanglobal
# YahooNews
# MarkEidemCS
# MSFTGameDev
# KevinHincks_TDA
# TDANetwork
# alamentarius
# AlAbaroa
# mikeshorrcbot
# tinoboccarsi
# DiscipleofTrend
# OJRenick
# ProsperTrading
# cboesib
# callieabost
# conorsen
# aztecs99
# IronbeamFutures
# leadlagreport
# RampCapitalLLC
# JackieDeAngelis
# jimiuorio
# 247WallSt
# HedgeDirty
# BrialWissmanCS
# TruthGundlach
# MarketRebels
# Stocktwits
# t3live
# bbands
# mikeelliott
# CEOLIVE
# business
# GreenlightCapit
# GreenLight_Fund
# IchanCarl
# nickperry
# KeeneOnMarket
# Wealth365Inc
# acornwealth
# AnthonyMaceroni
# RobInTheBlack
# cobra_trading
# DanZanger
# MarkArbeter
# nntaleb
# JayWoods3
# jeffkilburg
# jimtankersley
# Dan_Passarelli
# OptionPit
# jonnajarian
# petenajarian
# PetesAssistant
# Sassy_SPY
# BeyondTheTrades
# sentimentrader
# RussellRhoads
# CMEActiveTrader
# CBOE
# YWCAChicago
# DynamicMynds
# SmileyNews
# Borsredaktion
# ekkalundin
# OneTradingGroup
# ventiego
# Rushtime_In
# OptoCMC
# EquityArmorAdv
# SorabNY
# FactSet
# nathanattrill
# chamath
# crosshairtrader
# paulwoll
# charliebilello
# RobertJHoffman
# jessefelder
# CitronResearch
# sunchartist
# Jkylebass
# AsennaWealth
# bclund
# QTRResearch
# Downtown
# CordovaTrades
# StockCats
# KeithMcCullough
# LizAnnSonders
# fund_harry
# anthonycros1
# LPLResearch
# C_Barraud
# KathyJones
# TravisRhoden1
# JeffreyKleintop
# KimbleCharting
# TrendSpider
# ComfortablySmug
# galtg
# investmentnews
# NuveenInv
# wesbury
# theaney84
# DCBorthwick
# TheVoz4Real
# LindasStocks
# msectors
# RedDogT3
# letsinvestnow
# SunriseTrader
# JMVala_Trades
# jsblokland
# BillFOXLA
# elonmusk
# dashofinsight
# Steven1_994
# GSCareers
# ChrisTremulis
# ProTrader_Mike
# StkConfidential
# MarketMakerSins
# marketmodel
# BuyPullbacks
# TMLTrader
# MarketSmith
# elerianm
# lloydblankfein
# RayDalio
# stockholderusa
# vmwareclouddell
# DerivativesDude
# 1humbletrader
# MonacoTrader
# Schnellinvestor
# Codeman048
# Rayner_Teo
# SilviaBellrock
# FocusedValue
# alex_pocock
# 54thOld
# retheauditors
# nicola_m_white
# KristinBentz
# Stallone_re
# akseliristola
# lstauff
# HariMrMarket
# OneHappyInKaria
# StockMasta_Flex
# RGibsonSmith
# RobertFBarba
# RangelandCap
# Zuri73665951
# Stocktrader
# bam_trader
# RealJakeMoore
# meydeymeydeymey
# FriedrichHofma1
# AlanHarveyMeds
# MarcelDietsch
# ProfessorHt
# BrabyRandy
# jackeazy
# BTCanalyst66
# sven_europa
# MFollett_TDA
# ramp_uup
# wassi_wasim
# bullishmatt
# FinIQTrading
# tgvrrr
# henryurbano
# SteveVannelli
# GraysonRoze
# ViventiGiorgio
# RationalTrader_
# doesitmakemoney
# flagtrader010
# dilipreddy111
# swaraj987
# wattsy13
# Degennaroinvest
# chicodurden21
# adcapitalforex
# FP_markets
# mono_trader
# FtmKiers
# Mr_Jilians
# YasirIJara
# vipster61
# WizDayTrader
# LiveLoveHelp11
# BitScalp
# raultrades
# Distaili
# UltraTurtle7589
# Devilpit82
# tgod01
# BillMcElroy
# md_amit
# masatrader1
# fightforthesky
# marketminute
# GenZTrustFund
# PlusEvCapital
# BallStreetCap
# JoshuaTreeFund
# jbancs1
# jerermy29042269
# TradetheAction
# breakoutplays1
# FlowValue
# PabloBaiocchi1
# LxLongshort
# 4JusticeReform
# PS_81_
# RanchiWale
# melostar369
# CapitalNotes
# reezcapital
# DayTrade_
# blueedged
# Cengizh89364238
# moscona_md
# MikoMikoTrading
# SrshRmynm
# CorgiPicks
# investmentwisdm
# sjaycoulter
# pokerwizardIL
# IBDinvestors
# szaman
# JBoorman
# Xiphos_Trading
# chessNwine
# pharris667
# hertcapital
# adambsterling
# Schuldensuehner
# ChinaBeigeBook
# matthewstoller
# christophercamp
# VanceBarse
# InvariantPersp1
# SSlyper
# biancoresearch
# RaoulGMI
# LukeGromen
# NorthmanTrader
# 4Awesometweet
# philip00330562
# DiMartinoBooth
# greggutfeld
# mark_dow
# LMT978
# UmarAshraf
# armannein
# Rutkay_Dinc
# Wolfie0516
# meditationfarm
# MelindaMcCubbin
# BigTurkey36
# GeorgePang_
# adamsinvesting
# michaelsantoli
# RevShark
# DKellerCMT
# SamanthaaPort
# DeltaNinety
# timothysykes
# ScalpMaster1
# donthink2match
# BridgetPhetasy
# madaznfootballr
# TSXtrad3r
# Canny4
# nextbigtrade
# caroljsroth
# ForexLive
# AbbottNews
# stevenplace
# AT09_Trader
# InvestorsLive
# merrittblack
# stoolpresidente
# GoldmanSachs
# Attackim
# markminervini
# Quicktake
# AdamKoos
# ukarlewitz
# allstarcharts
# RyanMorse33
# Callum_Thomas
# topdowncharts
# cmtHot20
# CMTMosqueda
# CMTSquares
# ArthurHill
# TechCharts
# gshah26
# aftermidnite
# chartsmarter
# jkrinskypga
# pat_hennessy
# AriWald
# CaroMT
# RyanDetrick
# the_chart_life
# BruniCharting
# mnkahn
# CMTAssociation
# MarkNewtonCMT
# FusionptCapital
# harmongreg
# gtlackey
# srgtrader
# BruceKamich
# irusha
# KRose_TDA
# PMullaly_TDA
# AndrewThrasher
# nomura_jp
# iSPYTrading
# chatwithtraders
# SJosephBurns
# sspencer_smb
# steenbab
# MikeBellafiore
# austinmitchyblu
# smbcapital
# thinkorswim
# RandyAFrederick
# federalreserve
# SchwabResearch
# TDAmeritrade
# CharlesSchwab
# realDonaldTrump
# muddywatersre
# KerrisdaleCap
# sprucepointcap
# lisaabramowicz1
# TheBubbleBubble
# alphatrends
# SquawkCNBC
# MarketWatch
# CNBCnow
# TheStreet
# SquawkStreet
# CNBC
# markets
# CNBCFastMoney
# jimcramer
# MadMoneyOnCNBC
# canuck2usa
# sanglucci
# OptionsHawk
# WallStJesus
# Delta_Desk
# rb_trader
# Traders4ACause
# mrockrulez
# PodcastLib
# EBBistro
# coreykindhart
# modern_rock
# CBCBusiness
# rcarrick
# MoneySense
# WSJ
# BNNBloomberg
# globeinvestor
# BusinessInsider
# cdnbiz
# fpinvesting
# TheEconomist
# FinanceCanada
# bankofcanada
# canadabusiness
# JoeNBC
# YahooFinanceCA
# HarvardBiz
# IBKR_TI
# CanRevAgency
# traders_tweets
# TradersCorner

# %%
columns
# Out:
# {'id', 'name', 'username'}

# %%
users
# Out:
# [{'id': 1443048757721972737, 'name': 'David', 'username': 'DavidScienceCom'},
#  {'id': 20972371, 'name': 'Dan Carlin', 'username': 'HardcoreHistory'},
#  {'id': 13334762, 'name': 'GitHub', 'username': 'github'},
#  {'id': 878268519032532992, 'name': 'Max Bulenda', 'username': 'maxbulenda'},
#  {'id': 1491138793163870213,
#   'name': 'Strategas Asset Management',
#   'username': 'strategasasset'},
#  {'id': 1535311072181231617,
#   'name': 'Compounding Quality',
#   'username': 'QCompounding'},
#  {'id': 1503117418071220230,
#   'name': 'Macro EU & US (previously investor743)',
#   'username': 'MacroEu'},
#  {'id': 1405268733489303557, 'name': 'Passant H', 'username': 'P12328197359'},
#  {'id': 4747641663, 'name': 'AGF', 'username': 'agf'},
#  {'id': 108021761,
#   'name': 'ValueWalk - Exclusive hedge fund info (below)',
#   'username': 'valuewalk'},
#  {'id': 245581702, 'name': 'Wes Gray 🇺🇸', 'username': 'alphaarchitect'},
#  {'id': 321372866, 'name': 'steven blitz', 'username': 'sblitz1'},
#  {'id': 778186350, 'name': 'Mikael Sarwe', 'username': 'MikaelSarwe'},
#  {'id': 1467804779690692608,
#   'name': 'Carl Hodson-Thomas 🇺🇦',
#   'username': 'PrometheusCHT'},
#  {'id': 1301910697, 'name': 'Vanda Research', 'username': 'vandaresearch'},
#  {'id': 2313837474, 'name': 'Ned Davis Research', 'username': 'NDR_Research'},
#  {'id': 206366801, 'name': 'Farah ElBahrawy', 'username': 'farahesque'},
#  {'id': 1335944061774155777,
#   'name': 'Absolute Return Partners',
#   'username': 'AbsoluteReturnP'},
#  {'id': 3236381990, 'name': 'Bloomberg Terminal', 'username': 'TheTerminal'},
#  {'id': 1199145208895725573, 'name': 'Stat Arb', 'username': 'quant_arb'},
#  {'id': 1200359005,
#   'name': 'Richard Yetsenga 叶森 🇦🇺 🇭🇰 🇹🇭 🇳🇱',
#   'username': 'ricyet'},
#  {'id': 1248962047867576321,
#   'name': 'International Institute of Finance and Accounting',
#   'username': 'Interna26692915'},
#  {'id': 497266110, 'name': 'Strategas', 'username': 'StrategasRP'},
#  {'id': 895213223724666880,
#   'name': 'Dr. Dominic Royé @dr_xeo@mstdn.social',
#   'username': 'dr_xeo'},
#  {'id': 1248579691415351296,
#   'name': 'Global_Macro',
#   'username': 'Marcomadness2'},
#  {'id': 1246136668014301184,
#   'name': 'App Economy Insights',
#   'username': 'EconomyApp'},
#  {'id': 1948928522, 'name': 'Michael Msika', 'username': 'mikamsika'},
#  {'id': 2991672322,
#   'name': '🏳️\u200d🌈 Patrick Krizan 🇺🇦',
#   'username': 'PatrickKrizan'},
#  {'id': 22073146,
#   'name': 'Mike Zaccardi, CFA, CMT',
#   'username': 'MikeZaccardi'},
#  {'id': 182910373, 'name': 'Ron Butler', 'username': 'ronmortgageguy'},
#  {'id': 46804450, 'name': 'ChicagoFed', 'username': 'ChicagoFed'},
#  {'id': 57333256, 'name': 'Michael Ashton', 'username': 'inflation_guy'},
#  {'id': 143477156, 'name': 'Dallas Fed', 'username': 'DallasFed'},
#  {'id': 12061032, 'name': 'Rui Ma 马睿', 'username': 'ruima'},
#  {'id': 380993093, 'name': 'Marc Rubinstein', 'username': 'MarcRuby'},
#  {'id': 17239967,
#   'name': 'ClevelandFedResearch',
#   'username': 'ClevFedResearch'},
#  {'id': 425134513,
#   'name': 'Richmond Fed Research',
#   'username': 'RichFedResearch'},
#  {'id': 15072071, 'name': 'New York Fed', 'username': 'NewYorkFed'},
#  {'id': 5402612, 'name': 'BBC Breaking News', 'username': 'BBCBreaking'},
#  {'id': 48001143, 'name': 'Phila Fed Research', 'username': 'PhilFedResearch'},
#  {'id': 120176950, 'name': 'Treasury Department', 'username': 'USTreasury'},
#  {'id': 246621297, 'name': 'George Gammon', 'username': 'GeorgeGammon'},
#  {'id': 1238572372954767360, 'name': 'Layoffs.fyi', 'username': 'Layoffsfyi'},
#  {'id': 340387261, 'name': 'Gavin Baker', 'username': 'GavinSBaker'},
#  {'id': 775175696645623808, 'name': 'Anas Alhajji', 'username': 'anasalhajji'},
#  {'id': 1688796138, 'name': 'Peter Zeihan', 'username': 'PeterZeihan'},
#  {'id': 1016854943087710208,
#   'name': 'Bison Interests',
#   'username': 'BisonInterests'},
#  {'id': 989912836901089282, 'name': 'Blockworks', 'username': 'Blockworks_'},
#  {'id': 1364226660, 'name': 'Jawad Mian', 'username': 'jsmian'},
#  {'id': 2323253005, 'name': 'Lyall Taylor', 'username': 'LT3000Lyall'},
#  {'id': 44127350, 'name': 'Paul Hodges', 'username': 'paulhodges1'},
#  {'id': 1540344422939983874,
#   'name': 'Forward Guidance',
#   'username': 'ForwardGuidance'},
#  {'id': 91704576, 'name': 'Vincent Deluard', 'username': 'VincentDeluard'},
#  {'id': 1374003455195545601,
#   'name': 'Darius Dale',
#   'username': '42macroDDale'},
#  {'id': 1453373812939141130,
#   'name': 'Calderwood Capital',
#   'username': 'calderwoodcap'},
#  {'id': 1343646616566292482, 'name': 'KEDM.com', 'username': 'KEDM_COM'},
#  {'id': 587074680, 'name': 'Jens Nordvig 🇩🇰🇺🇸🇺🇦', 'username': 'jnordvig'},
#  {'id': 784233687487393792,
#   'name': '𝐏𝐢𝐧𝐞𝐜𝐨𝐧𝐞 𝐌𝐚𝐜𝐫𝐨',
#   'username': 'pineconemacro'},
#  {'id': 220016580, 'name': 'fred hickey', 'username': 'htsfhickey'},
#  {'id': 3845158767, 'name': 'LongConvexity', 'username': 'LONGCONVEXITY'},
#  {'id': 718702333, 'name': 'Joseph Wang', 'username': 'FedGuy12'},
#  {'id': 40471897, 'name': 'John P. Hussman, Ph.D.', 'username': 'hussmanjp'},
#  {'id': 1245074816677416960,
#   'name': 'Hugh Hendry Eclectica',
#   'username': 'hendry_hugh'},
#  {'id': 588265724, 'name': 'contrarian 8888', 'username': 'contrarian8888'},
#  {'id': 2184669968, 'name': 'steph pomboy', 'username': 'spomboy'},
#  {'id': 1889587914,
#   'name': 'Le Shrub Sauvage 🌳🔥👹🇺🇦',
#   'username': 'agnostoxxx'},
#  {'id': 1961333743, 'name': 'Diogenes', 'username': 'WallStCynic'},
#  {'id': 30040642, 'name': 'Jared Dillian', 'username': 'dailydirtnap'},
#  {'id': 26266863, 'name': 'Michael Kao', 'username': 'UrbanKaoboy'},
#  {'id': 2584103654, 'name': 'Otavio (Tavi) Costa', 'username': 'TaviCosta'},
#  {'id': 2324608013, 'name': 'Kantro', 'username': 'MichaelKantro'},
#  {'id': 939121727581208576,
#   'name': 'David Rosenberg',
#   'username': 'EconguyRosie'},
#  {'id': 28626088,
#   'name': 'Josh Young \U0001f9ac🛢️',
#   'username': 'Josh_Young_1'},
#  {'id': 415921084, 'name': 'Grant Williams', 'username': 'ttmygh'},
#  {'id': 851431642950402048,
#   'name': 'AndreasStenoLarsen',
#   'username': 'AndreasSteno'},
#  {'id': 1531882200, 'name': 'Kuppy', 'username': 'hkuppy'},
#  {'id': 42688847, 'name': 'Variant Perception', 'username': 'VrntPerception'},
#  {'id': 122104218, 'name': 'Calamos Investments', 'username': 'Calamos'},
#  {'id': 1285002506326556672, 'name': 'Jake', 'username': 'ThriftyJake'},
#  {'id': 908808302, 'name': 'Tim Eriksen', 'username': 'eriksen_tim'},
#  {'id': 1182317397216288768,
#   'name': 'Brent Jackson',
#   'username': 'leavenpartners'},
#  {'id': 279036722, 'name': 'Jason Furman', 'username': 'jasonfurman'},
#  {'id': 1978953986,
#   'name': '찌 G 跻 じ 𝙎𝙚𝙣𝙥𝙖𝙞 of the 𝙃𝙚𝙣𝙩𝙖𝙞',
#   'username': 'DegenSpartan'},
#  {'id': 1491835810416664576,
#   'name': 'Binary Tree',
#   'username': 'BTA_Binary_Tree'},
#  {'id': 1550094509899489280,
#   'name': 'Daily Chartbook',
#   'username': 'dailychartbook'},
#  {'id': 1349027549586673664, 'name': 'MrBlonde', 'username': 'MrBlonde_macro'},
#  {'id': 225099584, 'name': 'Fisher Investments', 'username': 'fisherinvest'},
#  {'id': 371810750, 'name': 'Gregory Daco', 'username': 'GregDaco'},
#  {'id': 910357294109556736,
#   'name': 'Black Swan',
#   'username': 'RetirementRight'},
#  {'id': 3316376038,
#   'name': 'The Kobeissi Letter',
#   'username': 'KobeissiLetter'},
#  {'id': 2420903580, 'name': 'Pantheon Macro', 'username': 'PantheonMacro'},
#  {'id': 557490385, 'name': 'Bobby Molavi', 'username': 'babakmolavi'},
#  {'id': 1135846280582881281,
#   'name': 'Richard Dias',
#   'username': 'RichardDias_CFA'},
#  {'id': 196560018, 'name': 'Aaron J. Kennon', 'username': 'AaronKennon'},
#  {'id': 1103787444904824832,
#   'name': 'Joe Frankenfield',
#   'username': 'SagaPartners'},
#  {'id': 747426392472686592,
#   'name': 'Julien Bittel, CFA',
#   'username': 'BittelJulien'},
#  {'id': 1002761314199130113,
#   'name': 'TechTraderView',
#   'username': 'TechTraderView'},
#  {'id': 1265060880179507201,
#   'name': 'Larry Cheung, CFA',
#   'username': 'LarryCheungCFA'},
#  {'id': 1120564659805929473,
#   'name': 'Macro Charts',
#   'username': 'MacroCharts'},
#  {'id': 65174274, 'name': 'Fidelity Investments', 'username': 'Fidelity'},
#  {'id': 1249837235832098822,
#   'name': 'Congress Stock Watcher',
#   'username': 'SenateStock'},
#  {'id': 2964381029, 'name': 'S3 Partners', 'username': 'S3Partners'},
#  {'id': 22092119, 'name': 'Option Alpha', 'username': 'OptionAlpha'},
#  {'id': 57111966, 'name': 'EIA', 'username': 'EIAgov'},
#  {'id': 1133775629537513472,
#   'name': "Harvard's Growth Lab",
#   'username': 'HarvardGrwthLab'},
#  {'id': 1123716338302836737,
#   'name': 'MacroMarketsDaily',
#   'username': 'macro_daily'},
#  {'id': 113447996, 'name': 'PPG', 'username': 'PPGMacro'},
#  {'id': 719984228746817538, 'name': 'J Mintzmyer', 'username': 'mintzmyer'},
#  {'id': 1433698536932003841, 'name': 'Daisy', 'username': 'Cher1991la'},
#  {'id': 1344759366671589376, 'name': 'Alf', 'username': 'MacroAlf'},
#  {'id': 5831802, 'name': 'Bill Luby', 'username': 'VIXandMore'},
#  {'id': 3059083613, 'name': 'Eric Basmajian', 'username': 'EPBResearch'},
#  {'id': 15668539,
#   'name': 'UCLA Anderson School of Management',
#   'username': 'uclaanderson'},
#  {'id': 18918483, 'name': 'UCLA', 'username': 'UCLA'},
#  {'id': 28593464, 'name': 'Wiley Finance', 'username': 'wiley_finance'},
#  {'id': 1546222940, 'name': 'Andy Constan', 'username': 'dampedspring'},
#  {'id': 1427329350538465281, 'name': 'Tier1 Alpha', 'username': 't1alpha'},
#  {'id': 187539751, 'name': 'Daily Trade Alert', 'username': 'DailyTradeAlert'},
#  {'id': 423769635, 'name': '(((The Daily Shot)))', 'username': 'SoberLook'},
#  {'id': 116832244, 'name': 'Global X ETFs', 'username': 'GlobalXETFs'},
#  {'id': 1341087029048827904,
#   'name': 'cephalopod_v7_no_ftx_final_2.xlsx',
#   'username': 'macrocephalopod'},
#  {'id': 1065390722520621062,
#   'name': 'Jessica Nutt',
#   'username': 'JessicaNutt96'},
#  {'id': 1218958306565165056, 'name': 'StockWonk', 'username': 'StockWonk'},
#  {'id': 17906658, 'name': 'Kinfo', 'username': 'Kinfo'},
#  {'id': 1043172896254959618, 'name': 'Minutemen', 'username': 'Dividends123'},
#  {'id': 1014614006101757953,
#   'name': 'TD Asset Management',
#   'username': 'TDAM_Canada'},
#  {'id': 239026022, 'name': 'Sam Ro 📈', 'username': 'SamRo'},
#  {'id': 472269627, 'name': 'SumZero', 'username': 'SumZero'},
#  {'id': 3228602440, 'name': 'David Woo', 'username': 'Davidwoounbound'},
#  {'id': 37981503, 'name': 'Nareit', 'username': 'REITs_Nareit'},
#  {'id': 78100510, 'name': 'MIT Sloan Experts', 'username': 'mitsloanexperts'},
#  {'id': 1080824460389822464,
#   'name': 'Clear Harbor Asset Management',
#   'username': 'ClearHarborAM'},
#  {'id': 1039174245258027008,
#   'name': 'Voss Capital',
#   'username': 'CapitalVoss'},
#  {'id': 17217571,
#   'name': 'Institute for Supply Management',
#   'username': 'ism'},
#  {'id': 1225490224106627074,
#   'name': 'Alpha_Ex_LLC',
#   'username': 'Alpha_Ex_LLC'},
#  {'id': 78429986, 'name': 'Mercer', 'username': 'mercer'},
#  {'id': 76511168,
#   'name': 'S&P Global Market Intelligence',
#   'username': 'SPGMarketIntel'},
#  {'id': 1297239074005233666,
#   'name': 'Stockcircle',
#   'username': 'cheaperthanguru'},
#  {'id': 249157878, 'name': 'Congress Asset Mgt', 'username': 'CongressAsset'},
#  {'id': 1315395406180814853,
#   'name': 'Daniel S. Loeb',
#   'username': 'DanielSLoeb1'},
#  {'id': 7386292, 'name': 'Fred Destin', 'username': 'fdestin'},
#  {'id': 27707080, 'name': 'PIMCO', 'username': 'PIMCO'},
#  {'id': 390753374, 'name': 'AllianzGl', 'username': 'AllianzGI_view'},
#  {'id': 1253681618964881409,
#   'name': 'Lokken Investment Group, LLC',
#   'username': 'LokkenInvest'},
#  {'id': 89213126, 'name': 'Commonwealth', 'username': 'CommonwealthFN'},
#  {'id': 15485461, 'name': 'Tadas Viskanta', 'username': 'abnormalreturns'},
#  {'id': 633238141, 'name': 'Michael Mauboussin', 'username': 'mjmauboussin'},
#  {'id': 3993499935, 'name': 'Fulcrum Asset', 'username': 'FulcrumAsset'},
#  {'id': 718182886, 'name': 'Kris Sidial', 'username': 'Ksidiii'},
#  {'id': 836266048907276288, 'name': 'Julian Brigden', 'username': 'JulianMI2'},
#  {'id': 477964537, 'name': 'DNB Nyheter', 'username': 'DNB_Bank'},
#  {'id': 23390520, 'name': 'Paul Scolardi', 'username': 'super_trades'},
#  {'id': 975142905424896000, 'name': 'Shahid Saleem', 'username': 'SSalim0002'},
#  {'id': 1144984532,
#   'name': 'Julian Komar 🚨 Market Update Premium',
#   'username': 'BlogJulianKomar'},
#  {'id': 55004706, 'name': 'Manning & Napier', 'username': 'ManningNapier'},
#  {'id': 47657595, 'name': 'Russell Investments', 'username': 'Russell_Invest'},
#  {'id': 303916100,
#   'name': 'Thornburg Investment Management',
#   'username': 'ThornburgFunds'},
#  {'id': 62873331, 'name': 'teclaro.eth', 'username': 'TeCLaro'},
#  {'id': 277659937,
#   'name': 'The Caprock Group, Inc.',
#   'username': 'TheCaprockGroup'},
#  {'id': 205084813, 'name': 'Envestnet', 'username': 'FolioDx'},
#  {'id': 627526105, 'name': 'Sofia Horta e Costa', 'username': 'SofiaHCBBG'},
#  {'id': 860054898599055360, 'name': 'Molly', 'username': 'bigmagicdao'},
#  {'id': 111603894, 'name': 'テスタ', 'username': 'tesuta001'},
#  {'id': 1160400596, 'name': 'Ronnie Stoeferle', 'username': 'RonStoeferle'},
#  {'id': 94199437, 'name': 'Nicola Wealth', 'username': 'nicolawealth'},
#  {'id': 4382570173, 'name': 'True Trader', 'username': 'TrueTraderNet'},
#  {'id': 91836238, 'name': 'Daniel Crosby', 'username': 'danielcrosby'},
#  {'id': 1120974139, 'name': 'Ryan Nauman', 'username': 'LkTahoeBadger'},
#  {'id': 322796213, 'name': 'Hedge Fund Alert', 'username': 'HFAlert'},
#  {'id': 39108691, 'name': 'Figuring Out Money', 'username': 'mikepsilva'},
#  {'id': 881727243227197440,
#   'name': 'Euan Sinclair',
#   'username': 'SinclairEuan'},
#  {'id': 1271098637205020673,
#   'name': 'Stretching Spreads',
#   'username': 'FadingRallies'},
#  {'id': 706013932574613504, 'name': 'VJDementia', 'username': 'VJDementia'},
#  {'id': 327371108, 'name': 'david johnson', 'username': 'kellogg'},
#  {'id': 16862807, 'name': 'Andover', 'username': 'Andover'},
#  {'id': 199170156, 'name': 'Cem Karsan 🥐', 'username': 'jam_croissant'},
#  {'id': 4858859837, 'name': 'SqueezeMetrics', 'username': 'SqueezeMetrics'},
#  {'id': 865624663841320960,
#   'name': 'Breaking Market News',
#   'username': 'breakingmkts'},
#  {'id': 1149920315415224325,
#   'name': 'Weston Nakamura',
#   'username': 'acrossthespread'},
#  {'id': 14983508, 'name': 'Chris Camillo', 'username': 'ChrisCamillo'},
#  {'id': 44695601, 'name': 'Nic', 'username': 'racernic'},
#  {'id': 760345658, 'name': 'Brett Winton', 'username': 'wintonARK'},
#  {'id': 55308734,
#   'name': 'Stock Trader’s Almanac',
#   'username': 'AlmanacTrader'},
#  {'id': 422053038,
#   'name': 'Contrarian Investors',
#   'username': 'lincolnsamelson'},
#  {'id': 1360997626666049539,
#   'name': 'Coat Trader 🧠',
#   'username': 'CoatTrader'},
#  {'id': 868743872159068162, 'name': 'T_Money', 'username': 'T_Money610'},
#  {'id': 1264971881247014912,
#   'name': 'ProtalixBio',
#   'username': 'Protalix_Bio'},
#  {'id': 97358939, 'name': 'OmahaCharts, CMT', 'username': 'omahacharts'},
#  {'id': 3344603963, 'name': 'ReSolve Asset Mgmt', 'username': 'InvestReSolve'},
#  {'id': 2432059932,
#   'name': 'cis@株 先物 FX 仮想通貨 リネレボ',
#   'username': 'cissan_9984'},
#  {'id': 11772752, 'name': 'Ron Bertino', 'username': 'ronbertino'},
#  {'id': 1113534617733214208, 'name': 'BPTfeed', 'username': 'BpTfeed'},
#  {'id': 149571760, 'name': 'Eric Balchunas', 'username': 'EricBalchunas'},
#  {'id': 855121724555223040, 'name': 'LEI', 'username': 'LoneCapital'},
#  {'id': 32362720, 'name': 'JT', 'username': 'TCMLLC'},
#  {'id': 27801361, 'name': 'Marcus Lemonis', 'username': 'marcuslemonis'},
#  {'id': 1093960278285434880,
#   'name': 'The Market Ear',
#   'username': 'themarketear'},
#  {'id': 1122679579, 'name': 'Yuriy Matso', 'username': 'yuriymatso'},
#  {'id': 2180410538, 'name': 'SVM Asset Management', 'username': 'SVMAsset'},
#  {'id': 41198196, 'name': 'Miki Hughes', 'username': 'MikiHughes166'},
#  {'id': 943155570386841600,
#   'name': 'Ben Lichtenstein',
#   'username': 'FuturesBen_TDAN'},
#  {'id': 719713329435000833,
#   'name': 'Scott Connor',
#   'username': 'ScottConnor_TDA'},
#  {'id': 23221109, 'name': 'Sean McLaughlin, NLD 📈', 'username': 'chicagosean'},
#  {'id': 287548299, 'name': 'Paul Wimmers', 'username': 'paulwimmers'},
#  {'id': 2758517289, 'name': 'brian self', 'username': 'SelfBrian'},
#  {'id': 117382717, 'name': 'IG', 'username': 'IGcom'},
#  {'id': 1001154983881035776, 'name': '𝐈𝐈𝐈', 'username': '____3rd____'},
#  {'id': 14831515, 'name': 'Glencore', 'username': 'Glencore'},
#  {'id': 87819956, 'name': 'Yildiray Cinar', 'username': 'ycinar'},
#  {'id': 15637008, 'name': 'Nationwide', 'username': 'Nationwide'},
#  {'id': 122711228, 'name': 'Greg Capra', 'username': 'GregCapra'},
#  {'id': 257661718, 'name': 'Andrew Scott Clarke', 'username': 'ascphoto'},
#  {'id': 101806773, 'name': 'TradersEXPO', 'username': 'TradersExpo'},
#  {'id': 48768144,
#   'name': 'Oliver L. Velez ⚡️ 13% Bitcoiner',
#   'username': 'olvelez007'},
#  {'id': 114782468, 'name': 'Carl Quintanilla', 'username': 'carlquintanilla'},
#  {'id': 3329898490, 'name': 'Mike Butler', 'username': 'tastytraderMike'},
#  {'id': 238174807, 'name': 'tastytrade', 'username': 'tastytrade'},
#  {'id': 2710651469, 'name': 'hot plays', 'username': 'ball8281'},
#  {'id': 2263452746, 'name': 'Tasha Keeney', 'username': 'TashaARK'},
#  {'id': 2398137084, 'name': 'ARK Invest', 'username': 'ARKInvest'},
#  {'id': 2579225425, 'name': 'Ritholtz Wealth', 'username': 'RitholtzWealth'},
#  {'id': 471541432, 'name': 'Mike Webster', 'username': 'mwebster1971'},
#  {'id': 1217143228803289090,
#   'name': 'Carter Braxton Worth',
#   'username': 'CarterBWorth'},
#  {'id': 2361631088, 'name': 'Cathie Wood', 'username': 'CathieDWood'},
#  {'id': 28007217,
#   'name': 'A Hedge Fund Manager',
#   'username': 'PerfectlyHedged'},
#  {'id': 150905976, 'name': 'Jason Aycock', 'username': 'AlphaJason'},
#  {'id': 360041082,
#   'name': 'AllianceBernstein (AB)',
#   'username': 'AB_insights'},
#  {'id': 193838214, 'name': 'Eric Wood', 'username': 'elkwood66'},
#  {'id': 8524892, 'name': 'Pearl', 'username': 'ppearlman'},
#  {'id': 44060322, 'name': 'Benzinga', 'username': 'Benzinga'},
#  {'id': 19888892, 'name': 'Michael Cammarata', 'username': 'mikecammarata'},
#  {'id': 13471032, 'name': 'JasonRaznick', 'username': 'JasonRaznick'},
#  {'id': 1170296953, 'name': 'Eve Boboch', 'username': 'EBoboch'},
#  {'id': 74980828, 'name': 'Subhadip Nandy', 'username': 'SubhadipNandy16'},
#  {'id': 3368482106, 'name': 'GuruLeaks', 'username': 'Guruleaks1'},
#  {'id': 202375506, 'name': 'Tom Hearden', 'username': 'followtheh'},
#  {'id': 36499730, 'name': 'Kathy Lien', 'username': 'kathylienfx'},
#  {'id': 431815660,
#   'name': 'Matt Caruso, CFA, CMT',
#   'username': 'Trader_mcaruso'},
#  {'id': 4150644011,
#   'name': 'Amber Andrews - T3 Live',
#   'username': 'AmCapTrader'},
#  {'id': 1160532342, 'name': 'T3 Trading Group', 'username': 'T3TradingGroup'},
#  {'id': 1364930179, 'name': 'Warren Buffett', 'username': 'WarrenBuffett'},
#  {'id': 1276649155906191363,
#   'name': 'Stock Avenue',
#   'username': 'StockAvenue'},
#  {'id': 142351603, 'name': 'Marc Chaikin', 'username': 'marcchaikin'},
#  {'id': 806664930564796418,
#   'name': 'Edward O. Thorp',
#   'username': 'EdwardOThorp'},
#  {'id': 4650290532, 'name': 'Vineer Bhansali', 'username': 'longtailalpha'},
#  {'id': 19997064, 'name': 'Meb Faber', 'username': 'MebFaber'},
#  {'id': 41516710, 'name': 'Eddy Elfenbein', 'username': 'EddyElfenbein'},
#  {'id': 1173770081295200263,
#   'name': 'Dragonfly ＞|＜',
#   'username': 'dragonfly_xyz'},
#  {'id': 56562803, 'name': 'Peter Schiff', 'username': 'PeterSchiff'},
#  {'id': 1144659664455553025,
#   'name': 'ChicagoAnalytic',
#   'username': 'AnalyticChicago'},
#  {'id': 558291075, 'name': 'Katie Stockton, CMT', 'username': 'StocktonKatie'},
#  {'id': 1156656695038357504, 'name': 'SpotGamma', 'username': 'spotgamma'},
#  {'id': 18856867, 'name': 'zerohedge', 'username': 'zerohedge'},
#  {'id': 82142636, 'name': 'Derald Muniz', 'username': '1nvestor'},
#  {'id': 47839554, 'name': 'Scott Shellady', 'username': 'ScottTheCowGuy'},
#  {'id': 805463901576069120,
#   'name': 'WingGirl Trader',
#   'username': 'WingGirlTrader'},
#  {'id': 1393603976, 'name': 'tradewithjoe', 'username': 'tradewithjoe'},
#  {'id': 788333744, 'name': 'Ross Cameron', 'username': 'DayTradeWarrior'},
#  {'id': 2901962658, 'name': 'Live Traders', 'username': 'Live_Traders'},
#  {'id': 2493278845, 'name': 'The Empty Robot', 'username': 'theemptyrobot'},
#  {'id': 80697114, 'name': 'Dennis Dick, CFA', 'username': 'TripleDTrader'},
#  {'id': 484800516, 'name': 'True Trading Group', 'username': 'TrueTradingGrp'},
#  {'id': 971144858697117701,
#   'name': 'Michael Edward',
#   'username': 'MikeEdward_TTG'},
#  {'id': 991518863664742400,
#   'name': 'Equity Specialist 5175 OS',
#   'username': 'EquitiesPlayer'},
#  {'id': 2865349016, 'name': 'Paco', 'username': '77STPaco'},
#  {'id': 127756423, 'name': 'christmas garland', 'username': 'garlandrg'},
#  {'id': 136136326, 'name': 'Earnings Whispers', 'username': 'eWhispers'},
#  {'id': 1047181242007937024,
#   'name': 'Quant@Python',
#   'username': 'BeingHorizontal'},
#  {'id': 246585278, 'name': 'Cody Pavlak', 'username': 'OddStockTrader'},
#  {'id': 29532510, 'name': 'chris', 'username': 'tradesbychris'},
#  {'id': 444772459, 'name': 'Vance Harwood', 'username': '6_Figure_Invest'},
#  {'id': 1211299208851947520,
#   'name': 'Dr. Thorsten Krauss',
#   'username': 'Th_Krauss'},
#  {'id': 597104499, 'name': 'Eli Mintz', 'username': 'VixCentral'},
#  {'id': 877533545400610817,
#   'name': '🇺🇸Country Club Brandon🇺🇸',
#   'username': 'BogeyBoiBrandon'},
#  {'id': 763932567762456576,
#   'name': "Qayyum ('Q') Rajan, CFA",
#   'username': 'qayyumrajan'},
#  {'id': 601154827, 'name': 'Luke Kawa', 'username': 'LJKawa'},
#  {'id': 1060345755486040064, 'name': 'Dave Mazza', 'username': 'MazzaDave'},
#  {'id': 1310763212, 'name': 'Michael Antonelli', 'username': 'BullandBaird'},
#  {'id': 771709986800078848,
#   'name': 'Andrew H. Smith',
#   'username': 'theandrewhsmith'},
#  {'id': 87347379, 'name': 'Chris Robinson', 'username': 'cer_hedge'},
#  {'id': 407430954, 'name': 'Jenny Horne', 'username': 'J_B_Horne'},
#  {'id': 20169416, 'name': 'Tracy Alloway', 'username': 'tracyalloway'},
#  {'id': 958794005713530881,
#   'name': 'Richard Roeper',
#   'username': 'RichardERoeper'},
#  {'id': 1007702190075461632,
#   'name': 'C21 Investments',
#   'username': 'C21Investments'},
#  {'id': 843930860692930560, 'name': 'CB1 Capital', 'username': 'CB1Cap'},
#  {'id': 110463712,
#   'name': '361 Capital, a division of Hamilton Lane',
#   'username': '361Capital'},
#  {'id': 39549428, 'name': 'Todd Harrison', 'username': 'todd_harrison'},
#  {'id': 73465112, 'name': 'AGTrader', 'username': 'ag_trader'},
#  {'id': 803172566, 'name': 'Vic Niederhoffer', 'username': 'VicNiederhoffer'},
#  {'id': 28369153, 'name': "Jim O'Shaughnessy", 'username': 'jposhaughnessy'},
#  {'id': 250362250, 'name': 'Michael Lamothe', 'username': 'MichaelGLamothe'},
#  {'id': 28571999, 'name': 'Bespoke', 'username': 'bespokeinvest'},
#  {'id': 171687263, 'name': 'Schwab4RIAs', 'username': 'Schwab4RIAs'},
#  {'id': 89043072, 'name': 'Jason Zweig', 'username': 'jasonzweigwsj'},
#  {'id': 1053699875496431617,
#   'name': 'The Market Huddle',
#   'username': 'TheMarketHuddle'},
#  {'id': 15492201, 'name': 'Kevin Muir', 'username': 'kevinmuir'},
#  {'id': 22067198, 'name': 'Dean Devlin', 'username': 'Dean_Devlin'},
#  {'id': 379134131, 'name': 'Steve Sosnick', 'username': 'SteveSosnick'},
#  {'id': 2317876500, 'name': 'BlackBoxStocks', 'username': 'BlackBoxStocks'},
#  {'id': 2695448612, 'name': 'Colibri Trader', 'username': 'priceinaction'},
#  {'id': 25882361, 'name': 'Jerry Parker', 'username': 'rjparkerjr09'},
#  {'id': 23002939, 'name': 'The Chartist', 'username': 'thechartist'},
#  {'id': 704462624050716672,
#   'name': 'Justin Nielsen',
#   'username': 'IBD_JNielsen'},
#  {'id': 1544385433, 'name': 'Chris Gessel', 'username': 'IBD_CGessel'},
#  {'id': 1546201075, 'name': 'Ken Shreve', 'username': 'IBD_KShreve'},
#  {'id': 2788398967, 'name': 'Alissa Coram', 'username': 'AlissaCoram'},
#  {'id': 34837057, 'name': 'maribeth', 'username': 'mb_willoughby'},
#  {'id': 397230151, 'name': 'Option Millionaires', 'username': 'OMillionaires'},
#  {'id': 3376824064, 'name': 'Options Mike', 'username': 'OptionsMike'},
#  {'id': 1007420368288714754, 'name': 'Tom', 'username': 'TradingThomas3'},
#  {'id': 93529573, 'name': 'Michael Batnick', 'username': 'michaelbatnick'},
#  {'id': 284278132, 'name': 'Morgan Housel', 'username': 'morganhousel'},
#  {'id': 1528558014,
#   'name': 'Patrick OShaughnessy',
#   'username': 'patrick_oshag'},
#  {'id': 261705971, 'name': 'Dan McMurtrie', 'username': 'SuperMugatu'},
#  {'id': 264370502, 'name': 'Chris Ciovacco', 'username': 'CiovaccoCapital'},
#  {'id': 1851508262,
#   'name': 'Citywire Funds Fanatic',
#   'username': 'FundFanatic'},
#  {'id': 3344056131, 'name': 'Jarno Eerikainen', 'username': 'Jattitude73'},
#  {'id': 1138547264736116736, 'name': 'James Boyd', 'username': 'JBoyd_TDA'},
#  {'id': 69279952, 'name': 'Christian Mischler', 'username': 'Chris_Mischler'},
#  {'id': 823766058909761536,
#   'name': 'Lyn Alden',
#   'username': 'LynAldenContact'},
#  {'id': 18069591, 'name': 'Michael Covel', 'username': 'Covel'},
#  {'id': 2308639909, 'name': 'Tom Basso', 'username': 'basso_tom'},
#  {'id': 704391334128394240,
#   'name': 'Allie Beth Stuckey',
#   'username': 'conservmillen'},
#  {'id': 20707966, 'name': 'Liz Claman', 'username': 'LizClaman'},
#  {'id': 537476904, 'name': 'Mark Phillips', 'username': 'RatPackTrader'},
#  {'id': 1673912810,
#   'name': 'vickileedillard.eth',
#   'username': 'VickiLeeDillard'},
#  {'id': 2679880238,
#   'name': 'Angelica Merie Amarand 905175',
#   'username': 'AngelicaAmarand'},
#  {'id': 217246038, 'name': 'Dan', 'username': 'd1rtydan'},
#  {'id': 1473023792, 'name': 'Ed Borgato', 'username': 'EdBorgato'},
#  {'id': 17676664, 'name': 'SiteGround', 'username': 'SiteGround'},
#  {'id': 4745753118, 'name': 'Upslope Capital', 'username': 'UpslopeCapital'},
#  {'id': 2721164528, 'name': 'East 🇹🇼', 'username': 'east_cap'},
#  {'id': 15865596, 'name': 'whalewisdom', 'username': 'whalewisdom'},
#  {'id': 1087276123, 'name': 'Mo', 'username': 'mochitown'},
#  {'id': 39822256, 'name': 'Casey', 'username': 'CaseysCharts'},
#  {'id': 995543502, 'name': 'Michael', 'username': 'profplum99'},
#  {'id': 4814182687, 'name': 'Erik Townsend 🛢️', 'username': 'ErikSTownsend'},
#  {'id': 594744288, 'name': 'Jim Leitner', 'username': 'LeitnerJim'},
#  {'id': 1134895477902708736, 'name': 'Macro Hive', 'username': 'Macro_Hive'},
#  {'id': 1102755062449954816, 'name': 'countstep', 'username': 'countstep1'},
#  {'id': 583517629, 'name': 'Santiago Capital', 'username': 'SantiagoAuFund'},
#  {'id': 335452018,
#   'name': 'Michael Lebowitz, CFA',
#   'username': 'michaellebowitz'},
#  {'id': 1118158654925090816,
#   'name': 'Fortified Enterprises',
#   'username': 'FortifiedEnter1'},
#  {'id': 955824055055089664,
#   'name': 'Amandeep Singh',
#   'username': 'Aman__Deep'},
#  {'id': 20253024, 'name': 'Tracy (𝒞𝒽𝒾 )', 'username': 'chigrl'},
#  {'id': 44366481, 'name': 'HULK', 'username': 'HulkCapital'},
#  {'id': 775762508271550465,
#   'name': 'Mike Coolbaugh',
#   'username': 'elementmacro'},
#  {'id': 20449296, 'name': "Barron's", 'username': 'barronsonline'},
#  {'id': 2159521964, 'name': 'Nivallia', 'username': 'Nivallia'},
#  {'id': 97530284, 'name': 'Ben Carlson', 'username': 'awealthofcs'},
#  {'id': 972678867713515520,
#   'name': 'Volatility Quant',
#   'username': 'VolatilityQ'},
#  {'id': 272696832,
#   'name': 'Benn Eifert \U0001f977🏴\u200d☠️',
#   'username': 'bennpeifert'},
#  {'id': 480913935, 'name': 'Adam Butler', 'username': 'GestaltU'},
#  {'id': 337914139, 'name': 'Darren 🎄🌟🎁', 'username': 'ReformedTrader'},
#  {'id': 953039267923681280,
#   'name': 'CoiledSpringCapital, CMT',
#   'username': 'coiledspringcap'},
#  {'id': 401695886, 'name': 'Trent Derrick,CMT', 'username': 'trent_d_legacy'},
#  {'id': 1066738539923152898, 'name': 'Short', 'username': 'Shorteverythin1'},
#  {'id': 706472880213778433, 'name': 'Anthony', 'username': 'anthony113742'},
#  {'id': 447129562, 'name': 'FedProm 💃🏻', 'username': 'FedProm'},
#  {'id': 38476367, 'name': 'Helene Meisler', 'username': 'hmeisler'},
#  {'id': 1090201846415798272,
#   'name': 'Spurs90🇬🇧🇺🇦',
#   'username': 'kaneinthename'},
#  {'id': 163648850, 'name': 'Doug Rumer', 'username': 'TradeWithDoug'},
#  {'id': 64657863, 'name': 'Patrick Chovanec', 'username': 'prchovanec'},
#  {'id': 60880381, 'name': 'Robin Wigglesworth', 'username': 'RobinWigg'},
#  {'id': 15640586, 'name': 'Sid Prabhu', 'username': 'sidprabhu'},
#  {'id': 1075589721957355521,
#   'name': 'Michael Krause',
#   'username': 'michaelbkrause'},
#  {'id': 1165754549535236098, 'name': 'stevekavdc', 'username': 'stevekavdc'},
#  {'id': 18812572, 'name': '60 Minutes', 'username': '60Minutes'},
#  {'id': 21187702, 'name': 'Youyang Gu', 'username': 'youyanggu'},
#  {'id': 977983631179337729,
#   'name': 'SystematiCK Trader',
#   'username': 'SystematiCK_'},
#  {'id': 541253226, 'name': 'jack schwager', 'username': 'jackschwager'},
#  {'id': 1158824447039590401,
#   'name': 'Randy Watts',
#   'username': 'Randy_Watts_'},
#  {'id': 714544888260509697, 'name': 'Leif Soreide', 'username': 'LeifSoreide'},
#  {'id': 727977413418745857,
#   'name': "William O'Neil + Co.",
#   'username': 'williamoneilco'},
#  {'id': 1183077103098572800, 'name': 'TRADER', 'username': 'TradingHaven'},
#  {'id': 345525945, 'name': 'emini', 'username': 'TicTocTick'},
#  {'id': 3655695736, 'name': 'James Fournier', 'username': 'JamesFournier'},
#  {'id': 172828800, 'name': 'Alin Puian', 'username': 'AlinPuian'},
#  {'id': 2704294333, 'name': '*Walter Bloomberg', 'username': 'DeItaone'},
#  {'id': 112046144, 'name': 'Gold Mansacks', 'username': 'Gold_Mansack'},
#  {'id': 27746125, 'name': 'hedgopia', 'username': 'hedgopia'},
#  {'id': 91478624, 'name': 'Forbes', 'username': 'Forbes'},
#  {'id': 45202420, 'name': 'Clair Lee, M.S.', 'username': 'clair520'},
#  {'id': 1001577714996989960,
#   'name': 'TplusTwo Holdings',
#   'username': 'TplusTwoHolding'},
#  {'id': 860332728, 'name': 'James Jude', 'username': 'Jimmyjude13'},
#  {'id': 210153565, 'name': 'David Settle, CMT', 'username': 'davidsettle42'},
#  {'id': 18300968, 'name': 'George Pearkes', 'username': 'pearkes'},
#  {'id': 232120274, 'name': 'Jesse Livermore', 'username': 'Jesse_Livermore'},
#  {'id': 737705735446892544,
#   'name': 'Blue Orca Capital',
#   'username': 'blueorcainvest'},
#  {'id': 2268219073, 'name': 'Patrick Walker', 'username': 'PatrickWalker56'},
#  {'id': 3511692614,
#   'name': 'David Berthon-Jones',
#   'username': 'berthon_jones'},
#  {'id': 758386485846544384, 'name': 'Will Meade', 'username': 'realwillmeade'},
#  {'id': 729435789411618817,
#   'name': 'Adam Mancini',
#   'username': 'AdamMancini4'},
#  {'id': 766312509829705728, 'name': 'Tony Greer', 'username': 'TgMacro'},
#  {'id': 37918984, 'name': 'Ian Cassel', 'username': 'iancassel'},
#  {'id': 22867489, 'name': 'Thomas Thornton', 'username': 'TommyThornton'},
#  {'id': 156058889, 'name': 'Tom Dante', 'username': 'Trader_Dante'},
#  {'id': 746492078914437120,
#   'name': 'Gregory Krupinski',
#   'username': 'G_krupins'},
#  {'id': 801116888, 'name': 'Christian Fromhertz 🇺🇸', 'username': 'cfromhertz'},
#  {'id': 922998314349445120, 'name': 'ivanhoff.com', 'username': 'ivanhoff2'},
#  {'id': 25366284, 'name': 'Angela Miles', 'username': 'AngieMiles'},
#  {'id': 2682092490,
#   'name': 'OptionSellingAddict',
#   'username': 'ShortVixTrade'},
#  {'id': 22774516, 'name': 'Steve Sears', 'username': 'sm_sears'},
#  {'id': 18131006, 'name': 'BGR', 'username': 'BGR'},
#  {'id': 18963870, 'name': 'Ira Michael Blonder', 'username': 'mikethebbop'},
#  {'id': 355866075, 'name': 'modest proposal', 'username': 'modestproposal1'},
#  {'id': 59485976, 'name': 'PSK2329 - JHC', 'username': 'psk2329'},
#  {'id': 19052568, 'name': 'cybercash28', 'username': 'MadMraket'},
#  {'id': 84281104, 'name': 'Credit Suisse', 'username': 'CreditSuisse'},
#  {'id': 1155522630, 'name': 'J.P. Morgan', 'username': 'jpmorgan'},
#  {'id': 426159377, 'name': 'Morgan Stanley', 'username': 'MorganStanley'},
#  {'id': 360685668, 'name': 'Merrill Lynch', 'username': 'MerrillLynch'},
#  {'id': 888118103095115780,
#   'name': 'Robin Brooks',
#   'username': 'RobinBrooksIIF'},
#  {'id': 15823646, 'name': 'Sarah Frier', 'username': 'sarahfrier'},
#  {'id': 1215601749542809600,
#   'name': 'Joanne Griffin',
#   'username': 'Joanne_AdaptIQ'},
#  {'id': 3094464720, 'name': 'Alex Zukin', 'username': 'AlexZukin'},
#  {'id': 1170432259, 'name': 'Hal Marshall', 'username': 'HalMarshall2309'},
#  {'id': 93295809, 'name': 'Jim Rickards', 'username': 'JamesGRickards'},
#  {'id': 761884866, 'name': 'Jay Van Sciver', 'username': 'HedgeyeIndstrls'},
#  {'id': 1069759314364153856,
#   'name': 'Andrew Freedman, CFA 🦅',
#   'username': 'HedgeyeComm'},
#  {'id': 81075524,
#   'name': 'Reuters Energy and Commodities',
#   'username': 'ReutersCommods'},
#  {'id': 1652541, 'name': 'Reuters', 'username': 'Reuters'},
#  {'id': 1533915450, 'name': 'Ron Bousso', 'username': 'ronbousso1'},
#  {'id': 195755593, 'name': 'Reuters Press Team', 'username': 'ReutersPR'},
#  {'id': 48598141, 'name': 'Jennifer Hiller', 'username': 'Jennifer_Hiller'},
#  {'id': 1647573157, 'name': 'Javier Blas', 'username': 'JavierBlas'},
#  {'id': 65739179,
#   'name': 'IHS Markit now S&P Global',
#   'username': 'IHSMarkit'},
#  {'id': 15936194, 'name': 'twilio', 'username': 'twilio'},
#  {'id': 1398759560, 'name': 'Robert Maguire', 'username': 'RobertMaguire_'},
#  {'id': 15250501, 'name': 'juthica', 'username': 'juthica'},
#  {'id': 1090072992, 'name': 'Expert Institute', 'username': 'ExpertInst'},
#  {'id': 341380711, 'name': 'ogf', 'username': 'ogfz_'},
#  {'id': 39480502, 'name': 'Tom Forrest', 'username': 'TommmyF'},
#  {'id': 2813111124, 'name': 'Jakubstadt Holdings', 'username': 'Jakubstadt'},
#  {'id': 913924445533741056,
#   'name': 'The Chart Report',
#   'username': 'TheChartReport'},
#  {'id': 1341255002, 'name': 'Joe Shipman', 'username': 'joe_shipman'},
#  {'id': 18719020, 'name': 'Hedgeye', 'username': 'Hedgeye'},
#  {'id': 2511153668, 'name': 'Jeffrey P. Snider', 'username': 'JeffSnider_AIP'},
#  {'id': 717926102614716417,
#   'name': 'Caitlin Long 🔑⚡️\U0001f7e0',
#   'username': 'CaitlinLong_'},
#  {'id': 2980272417, 'name': 'Don Friedman', 'username': 'DigitalDonF'},
#  {'id': 254280603,
#   'name': 'Mark W. Yusko 🐀 #TwoPointOneQuadrillion',
#   'username': 'MarkYusko'},
#  {'id': 18034541, 'name': 'Fitzstock', 'username': 'Fitzstock2004'},
#  {'id': 302545862, 'name': 'Andy Nyquist', 'username': 'andrewnyquist'},
#  {'id': 516980928, 'name': 'Ben Johnson, CFA', 'username': 'MstarBenJohnson'},
#  {'id': 1031926601490083840, 'name': 'Tom White', 'username': 'TomWhite_TDAN'},
#  {'id': 2547045841,
#   'name': 'Bloke that trades stuff',
#   'username': 'southernmacro'},
#  {'id': 4715141781, 'name': 'Wolf King 🐺 🌌', 'username': 'Wolf_Dreams7'},
#  {'id': 3882872352, 'name': 'Sakura Artist', 'username': 'DreamWasArtist'},
#  {'id': 516072804, 'name': 'Raj Mahal', 'username': 'RajMahalTweets'},
#  {'id': 17437374, 'name': 'Lex van Dam', 'username': 'lexvandam'},
#  {'id': 16334857, 'name': 'Real Time Economics', 'username': 'WSJecon'},
#  {'id': 16085140, 'name': 'Tim McDonald', 'username': 'trmcdonald'},
#  {'id': 384445331, 'name': 'Steve Liesman', 'username': 'steveliesman'},
#  {'id': 140149665, 'name': 'Alan Brochstein, CFA', 'username': 'Invest420'},
#  {'id': 119372054, 'name': 'Becky Quick', 'username': 'BeckyQuick'},
#  {'id': 39264827, 'name': 'Guy Adami', 'username': 'GuyAdami'},
#  {'id': 271211220, 'name': 'Dan Nathan', 'username': 'RiskReversal'},
#  {'id': 39853973, 'name': 'Tim Seymour', 'username': 'timseymour'},
#  {'id': 15296897, 'name': 'Breaking News', 'username': 'MarketCurrents'},
#  {'id': 259214687, 'name': 'Prof. Mthuli Ncube', 'username': 'MthuliNcube'},
#  {'id': 863527548, 'name': 'Steve Hanke', 'username': 'steve_hanke'},
#  {'id': 966369090368614400,
#   'name': 'JB Mackenzie',
#   'username': 'JBMackenzie_TDA'},
#  {'id': 818839234756812804, 'name': 'Ben Watson', 'username': 'BenWatson_TDA'},
#  {'id': 183279521, 'name': 'Scott Minerd', 'username': 'ScottMinerd'},
#  {'id': 1018730376, 'name': 'Burt White', 'username': '_BurtWhite'},
#  {'id': 382267401, 'name': 'Anthony Valeri', 'username': 'Anthony_Valeri'},
#  {'id': 882891427, 'name': 'LPL Financial', 'username': 'LPL'},
#  {'id': 22088714, 'name': 'Cullen Roche', 'username': 'cullenroche'},
#  {'id': 455309376, 'name': 'Stephanie Link', 'username': 'Stephanie_Link'},
#  {'id': 14230772, 'name': 'Matt Levine', 'username': 'matt_levine'},
#  {'id': 814964403284115457,
#   'name': 'Nick Maggiulli',
#   'username': 'dollarsanddata'},
#  {'id': 2263437272, 'name': 'Sam Korus', 'username': 'skorusARK'},
#  {'id': 1576052886, 'name': 'Alex Gurevich', 'username': 'agurevich23'},
#  {'id': 68739089, 'name': 'Charles Gasparino', 'username': 'CGasparino'},
#  {'id': 875818111995437057, 'name': 'Sven Carlin', 'username': 'SvenCarlin'},
#  {'id': 855036990, 'name': 'Gunjan Banerji', 'username': 'GunjanJS'},
#  {'id': 24878730, 'name': 'Bob Iaccino', 'username': 'Bob_Iaccino'},
#  {'id': 300278863, 'name': 'Andrew Pancholi', 'username': 'AndrewPancholi'},
#  {'id': 145727858, 'name': 'Judy Khan Shaw', 'username': 'JudyKShaw'},
#  {'id': 1224764402278076416, 'name': 'FadeTheXX', 'username': 'FadeTheXX'},
#  {'id': 135379396, 'name': 'James Roppel', 'username': 'Upticken'},
#  {'id': 31064165, 'name': 'FXHedge', 'username': 'Fxhedgers'},
#  {'id': 21810002, 'name': 'Bill McBride', 'username': 'calculatedrisk'},
#  {'id': 38053161, 'name': 'Joseph Fahmy', 'username': 'jfahmy'},
#  {'id': 19182653, 'name': 'Institute of Trading', 'username': 'ITPM_com'},
#  {'id': 301638595, 'name': 'AntonKreil', 'username': 'AntonKreil'},
#  {'id': 595614462, 'name': 'Gregoire Dupont', 'username': 'GregoireDup'},
#  {'id': 454001408, 'name': 'Chris Quill', 'username': 'Chris_Quill'},
#  {'id': 1534167900, 'name': 'Carl Icahn', 'username': 'Carl_C_Icahn'},
#  {'id': 880412538625810432, 'name': 'Bill Ackman', 'username': 'BillAckman'},
#  {'id': 1111718590036828161,
#   'name': 'Empire Financial Research',
#   'username': 'EmpireResearch'},
#  {'id': 245206933, 'name': 'Whitney Tilson', 'username': 'WhitneyTilson'},
#  {'id': 296471931,
#   'name': 'Investments & Wealth Institute',
#   'username': 'iw_inst'},
#  {'id': 306850457, 'name': 'Michael C. Khouw', 'username': 'Michael_Khouw'},
#  {'id': 14740219, 'name': 'Amazon Music', 'username': 'amazonmusic'},
#  {'id': 326315947, 'name': 'Options Action', 'username': 'OptionsAction'},
#  {'id': 389048586, 'name': 'Patrick Boyle 💎', 'username': 'PatrickEBoyle'},
#  {'id': 707147232357683205,
#   'name': 'Volatility Trading',
#   'username': 'VolatilityVIX'},
#  {'id': 261457778, 'name': 'Dotan', 'username': 'PianoAround'},
#  {'id': 828411262090485760,
#   'name': 'Invest In Vol',
#   'username': 'investinvol'},
#  {'id': 419624323, 'name': 'Jermal Chandler', 'username': 'JermalChandler'},
#  {'id': 1092685123, 'name': 'Kevin Davitt', 'username': 'kpdavitt13'},
#  {'id': 40156330, 'name': 'Scott Gottlieb, MD', 'username': 'ScottGottliebMD'},
#  {'id': 168697720, 'name': 'Joe Tigay', 'username': 'JoeTigay'},
#  {'id': 3387457954, 'name': 'Spencer', 'username': 'vxx46'},
#  {'id': 2168684192, 'name': 'Daniel Deming', 'username': 'Djd551'},
#  {'id': 74164460, 'name': 'Asset TV', 'username': 'assettv'},
#  {'id': 2820189509,
#   'name': 'Swan Global Investments',
#   'username': 'swanglobal'},
#  {'id': 7309052, 'name': 'Yahoo News', 'username': 'YahooNews'},
#  {'id': 1238500719860150272, 'name': 'Mark Eidem', 'username': 'MarkEidemCS'},
#  {'id': 1057769718864461824,
#   'name': 'Microsoft Game Dev',
#   'username': 'MSFTGameDev'},
#  {'id': 966365716659228678,
#   'name': 'Kevin Hincks',
#   'username': 'KevinHincks_TDA'},
#  {'id': 872519322077470721,
#   'name': 'TD Ameritrade Network',
#   'username': 'TDANetwork'},
#  {'id': 752940576631250944,
#   'name': 'Alamentarius Optimistic 3/23/20 was not THE bottom',
#   'username': 'alamentarius'},
#  {'id': 1665919459, 'name': 'Al Abaroa', 'username': 'AlAbaroa'},
#  {'id': 22266161, 'name': 'Michael Shorr', 'username': 'mikeshorrcbot'},
#  {'id': 1470625315, 'name': 'Tino Boccarsi', 'username': 'tinoboccarsi'},
#  {'id': 882854310,
#   'name': '•Charlie Moon• 🌖’s 💰 Trades Ⓜ️Ⓜ️T',
#   'username': 'DiscipleofTrend'},
#  {'id': 1580555131, 'name': 'Oliver Renick', 'username': 'OJRenick'},
#  {'id': 634735245,
#   'name': 'Prosper Trading Academy',
#   'username': 'ProsperTrading'},
#  {'id': 2306988318, 'name': 'Scott Bauer', 'username': 'cboesib'},
#  {'id': 97786845, 'name': 'Callie Cox', 'username': 'callieabost'},
#  {'id': 70778344, 'name': 'Conor Sen', 'username': 'conorsen'},
#  {'id': 32778531, 'name': 'Bob Lang', 'username': 'aztecs99'},
#  {'id': 794372887, 'name': 'Ironbeam Futures', 'username': 'IronbeamFutures'},
#  {'id': 227755413,
#   'name': 'Michael A. Gayed, CFA',
#   'username': 'leadlagreport'},
#  {'id': 2214652482, 'name': 'Ramp Capital', 'username': 'RampCapitalLLC'},
#  {'id': 147409568, 'name': 'Jackie DeAngelis', 'username': 'JackieDeAngelis'},
#  {'id': 60622883, 'name': 'jim iuorio', 'username': 'jimiuorio'},
#  {'id': 17622474, 'name': '24/7 Wall St.', 'username': '247WallSt'},
#  {'id': 1253117263617691654,
#   'name': 'Dirty Texas Hedge',
#   'username': 'HedgeDirty'},
#  {'id': 888114220193075208,
#   'name': 'Brial Wissman',
#   'username': 'BrialWissmanCS'},
#  {'id': 861619895485726722,
#   'name': 'Jeffrey Gundlach',
#   'username': 'TruthGundlach'},
#  {'id': 817007725666242561,
#   'name': 'Market Rebellion',
#   'username': 'MarketRebels'},
#  {'id': 14886375, 'name': 'Stocktwits', 'username': 'Stocktwits'},
#  {'id': 14972202, 'name': 'T3 Live', 'username': 't3live'},
#  {'id': 54675700, 'name': 'John Bollinger', 'username': 'bbands'},
#  {'id': 15756049, 'name': 'CEORoadshow', 'username': 'mikeelliott'},
#  {'id': 38562627, 'name': 'Mike Elliott', 'username': 'CEOLIVE'},
#  {'id': 34713362, 'name': 'Bloomberg', 'username': 'business'},
#  {'id': 1191630295,
#   'name': 'Greenlight Capital',
#   'username': 'GreenlightCapit'},
#  {'id': 729103873, 'name': 'GreenLight Fund', 'username': 'GreenLight_Fund'},
#  {'id': 991779887475195905, 'name': 'Carl Ichan', 'username': 'IchanCarl'},
#  {'id': 14814994, 'name': 'Nick Perry', 'username': 'nickperry'},
#  {'id': 289556231, 'name': 'CEO of AlphaShark', 'username': 'KeeneOnMarket'},
#  {'id': 917495878239313922, 'name': 'Wealth365', 'username': 'Wealth365Inc'},
#  {'id': 516914814, 'name': 'Acorn Wealth', 'username': 'acornwealth'},
#  {'id': 1367765233, 'name': 'A. Maceroni 🍝', 'username': 'AnthonyMaceroni'},
#  {'id': 23368614, 'name': 'Rob Smith', 'username': 'RobInTheBlack'},
#  {'id': 607638633, 'name': 'Cobra Trading', 'username': 'cobra_trading'},
#  {'id': 49663664, 'name': 'Dan Zanger', 'username': 'DanZanger'},
#  {'id': 1399951764, 'name': 'Mark Arbeter, CMT', 'username': 'MarkArbeter'},
#  {'id': 381289719, 'name': 'Nassim Nicholas Taleb', 'username': 'nntaleb'},
#  {'id': 42154404, 'name': 'Jay Woods', 'username': 'JayWoods3'},
#  {'id': 222164515, 'name': 'Jeff Kilburg', 'username': 'jeffkilburg'},
#  {'id': 133947893, 'name': 'Jim Tankersley', 'username': 'jimtankersley'},
#  {'id': 39371002, 'name': 'Dan Passarelli', 'username': 'Dan_Passarelli'},
#  {'id': 122511616, 'name': 'Mark Sebastian', 'username': 'OptionPit'},
#  {'id': 14115408, 'name': 'Jon Najarian', 'username': 'jonnajarian'},
#  {'id': 14292717, 'name': 'Pete Najarian', 'username': 'petenajarian'},
#  {'id': 858812515, 'name': "Pete's Assistant", 'username': 'PetesAssistant'},
#  {'id': 375980238, 'name': 'Rachel Shasha, MS, MFT', 'username': 'Sassy_SPY'},
#  {'id': 830157525102317568,
#   'name': 'BeyondTheTrades',
#   'username': 'BeyondTheTrades'},
#  {'id': 7557352, 'name': 'SentimenTrader', 'username': 'sentimentrader'},
#  {'id': 23193379, 'name': 'Russell Rhoads', 'username': 'RussellRhoads'},
#  {'id': 2457018674,
#   'name': 'CME Active Trader',
#   'username': 'CMEActiveTrader'},
#  {'id': 16827489, 'name': 'Cboe', 'username': 'CBOE'},
#  {'id': 21437383, 'name': 'YWCA Chicago', 'username': 'YWCAChicago'},
#  {'id': 521445567, 'name': 'DyMynd', 'username': 'DynamicMynds'},
#  {'id': 1100765004415074304,
#   'name': 'Smiley Movement',
#   'username': 'SmileyNews'},
#  {'id': 2865669239, 'name': 'Direkt Börs', 'username': 'Borsredaktion'},
#  {'id': 217540848, 'name': 'Ekka Lundin', 'username': 'ekkalundin'},
#  {'id': 2411559404,
#   'name': 'One Trading Group',
#   'username': 'OneTradingGroup'},
#  {'id': 930770534719217664, 'name': 'v', 'username': 'ventiego'},
#  {'id': 1084883615865921537, 'name': 'Rushtime.In', 'username': 'Rushtime_In'},
#  {'id': 1026859783100485637,
#   'name': 'Opto 📈 Investing intelligence',
#   'username': 'OptoCMC'},
#  {'id': 974416497878622208,
#   'name': 'EquityArmorAdvisors',
#   'username': 'EquityArmorAdv'},
#  {'id': 1240129519, 'name': 'Trader Sorab ⭐️', 'username': 'SorabNY'},
#  {'id': 17473062, 'name': 'FactSet', 'username': 'FactSet'},
#  {'id': 3223940743, 'name': 'Nathan Attrill', 'username': 'nathanattrill'},
#  {'id': 3291691, 'name': 'Chamath Palihapitiya', 'username': 'chamath'},
#  {'id': 29854129, 'name': 'David Blair', 'username': 'crosshairtrader'},
#  {'id': 53215424, 'name': 'Woll Street', 'username': 'paulwoll'},
#  {'id': 1413027896, 'name': 'Charlie Bilello', 'username': 'charliebilello'},
#  {'id': 117289737, 'name': 'Rob Hoffman Trader', 'username': 'RobertJHoffman'},
#  {'id': 1473431, 'name': 'Jesse Felder', 'username': 'jessefelder'},
#  {'id': 236953420, 'name': 'Citron Research', 'username': 'CitronResearch'},
#  {'id': 45175974, 'name': 'Sunil Beri', 'username': 'sunchartist'},
#  {'id': 3005733012, 'name': '🇺🇸Kyle Bass🇺🇦', 'username': 'Jkylebass'},
#  {'id': 582390700, 'name': 'Assad Tannous', 'username': 'AsennaWealth'},
#  {'id': 207617302, 'name': 'Brian Lund', 'username': 'bclund'},
#  {'id': 1469603575, 'name': 'Quoth the Raven', 'username': 'QTRResearch'},
#  {'id': 22522178, 'name': 'Downtown Josh Brown', 'username': 'Downtown'},
#  {'id': 1098694844006977536,
#   'name': 'Julia Cordova✨',
#   'username': 'CordovaTrades'},
#  {'id': 60113926, 'name': 'StockCats', 'username': 'StockCats'},
#  {'id': 18378349, 'name': 'Keith McCullough', 'username': 'KeithMcCullough'},
#  {'id': 2961589380, 'name': 'Liz Ann Sonders', 'username': 'LizAnnSonders'},
#  {'id': 1081006211674394626,
#   'name': 'Hedge Fund Harry',
#   'username': 'fund_harry'},
#  {'id': 47473994, 'name': 'Anthony Cros', 'username': 'anthonycros1'},
#  {'id': 313335112, 'name': 'LPL Research', 'username': 'LPLResearch'},
#  {'id': 537175623, 'name': 'Christophe Barraud🛢🐳', 'username': 'C_Barraud'},
#  {'id': 2840691561, 'name': 'Kathy Jones', 'username': 'KathyJones'},
#  {'id': 1181603037430915072,
#   'name': 'Travis M Rhoden',
#   'username': 'TravisRhoden1'},
#  {'id': 44656218, 'name': 'Jeffrey Kleintop', 'username': 'JeffreyKleintop'},
#  {'id': 202915788, 'name': 'Chris Kimble', 'username': 'KimbleCharting'},
#  {'id': 969571031030616071, 'name': 'TrendSpider', 'username': 'TrendSpider'},
#  {'id': 17060573, 'name': 'Comfortably Smug', 'username': 'ComfortablySmug'},
#  {'id': 49120718, 'name': 'Bruce Weisman,CMT', 'username': 'galtg'},
#  {'id': 63781564, 'name': 'InvestmentNews', 'username': 'investmentnews'},
#  {'id': 33539627, 'name': 'Nuveen, a TIAA company', 'username': 'NuveenInv'},
#  {'id': 23136887, 'name': 'Brian Wesbury', 'username': 'wesbury'},
#  {'id': 2904604703, 'name': 'Tommy', 'username': 'theaney84'},
#  {'id': 170707174, 'name': 'Douglas Borthwick', 'username': 'DCBorthwick'},
#  {'id': 2974029189, 'name': 'Olivia Voz', 'username': 'TheVoz4Real'},
#  {'id': 946900007030050816, 'name': 'Linda Brown', 'username': 'LindasStocks'},
#  {'id': 1004433661603835904, 'name': 'MicroSectors', 'username': 'msectors'},
#  {'id': 455824771, 'name': 'Scott Redler', 'username': 'RedDogT3'},
#  {'id': 2900363608, 'name': 'RxTrader', 'username': 'letsinvestnow'},
#  {'id': 787439438964068352,
#   'name': 'Sunrise Trader',
#   'username': 'SunriseTrader'},
#  {'id': 2200605978, 'name': 'JMVala', 'username': 'JMVala_Trades'},
#  {'id': 51689310, 'name': 'jeroen blokland', 'username': 'jsblokland'},
#  {'id': 1071585991, 'name': 'Bill Melugin', 'username': 'BillFOXLA'},
#  {'id': 44196397, 'name': 'Elon Musk', 'username': 'elonmusk'},
#  {'id': 14290226, 'name': 'Jeff Miller', 'username': 'dashofinsight'},
#  {'id': 720973556767723521, 'name': 'stevendu', 'username': 'Steven1_994'},
#  {'id': 1229952996, 'name': 'Goldman Sachs Careers', 'username': 'GSCareers'},
#  {'id': 18972000, 'name': 'Chris Tremulis', 'username': 'ChrisTremulis'},
#  {'id': 3420574769, 'name': 'ProTrader_Mike', 'username': 'ProTrader_Mike'},
#  {'id': 84444981,
#   'name': 'Chart Pattern Stocks',
#   'username': 'StkConfidential'},
#  {'id': 930971073147031552,
# ...
#   'name': "Jack's Smirking Revenge",
#   'username': 'doesitmakemoney'},
#  {'id': 966352134588465153,
#   'name': 'Jacques Rademeyer',
#   'username': 'flagtrader010'},
#  {'id': 336759959, 'name': 'Dilip Reddy', 'username': 'dilipreddy111'},
#  {'id': 226138263, 'name': 'Swaraj Rai', 'username': 'swaraj987'},
#  {'id': 34804337, 'name': 'Jeff Watts', 'username': 'wattsy13'},
#  {'id': 2935877735,
#   'name': 'Cataldo De gennaro',
#   'username': 'Degennaroinvest'},
#  {'id': 996388959864451073,
#   'name': 'chico ⚡️🍊💊🏴',
#   'username': 'chicodurden21'},
#  {'id': 1225953270532722688,
#   'name': 'AD Capital - Copy Trading Service',
#   'username': 'adcapitalforex'},
#  {'id': 636777949, 'name': 'FP Markets', 'username': 'FP_markets'},
#  {'id': 975765467657834497,
#   'name': 'Matthew Monaco 🚀',
#   'username': 'mono_trader'},
#  {'id': 1043452936754479106, 'name': 'Kierss_', 'username': 'FtmKiers'},
#  {'id': 90568210, 'name': 'Zeugma Options', 'username': 'Mr_Jilians'},
#  {'id': 865501278, 'name': 'Yasir Iqbal', 'username': 'YasirIJara'},
#  {'id': 3730685243, 'name': 'Rob Vipperman', 'username': 'vipster61'},
#  {'id': 2966251421, 'name': 'Miguel Ferreira 🔮', 'username': 'WizDayTrader'},
#  {'id': 1025762176215261184, 'name': 'Love11', 'username': 'LiveLoveHelp11'},
#  {'id': 123826145, 'name': 'ًً', 'username': 'BitScalp'},
#  {'id': 817101261334073344, 'name': 'Raul Macias', 'username': 'raultrades'},
#  {'id': 2384133488, 'name': 'IBreakEven', 'username': 'Distaili'},
#  {'id': 1193253548277919744,
#   'name': 'Ultra Turtle',
#   'username': 'UltraTurtle7589'},
#  {'id': 198623017, 'name': 'Rob', 'username': 'Devilpit82'},
#  {'id': 34291979, 'name': 'TGOD01', 'username': 'tgod01'},
#  {'id': 421487178, 'name': 'Bill McElroy', 'username': 'BillMcElroy'},
#  {'id': 83394877, 'name': 'Amit Gupta', 'username': 'md_amit'},
#  {'id': 340066623, 'name': 'masatrader', 'username': 'masatrader1'},
#  {'id': 176998847, 'name': 'andrew fowler', 'username': 'fightforthesky'},
#  {'id': 26583295,
#   'name': "Michele 'Mish' Schneider",
#   'username': 'marketminute'},
#  {'id': 1224411055427768320,
#   'name': 'Goldbug.eth',
#   'username': 'GenZTrustFund'},
#  {'id': 930229454634283008,
#   'name': 'PlusEvCapital',
#   'username': 'PlusEvCapital'},
#  {'id': 1146049157251162113,
#   'name': 'Ball Street | Investing Ideas & Education',
#   'username': 'BallStreetCap'},
#  {'id': 109179305, 'name': 'JTF Options', 'username': 'JoshuaTreeFund'},
#  {'id': 1189972345714302983, 'name': 'Finbancs', 'username': 'jbancs1'},
#  {'id': 1243897944476090369,
#   'name': 'Jeremias',
#   'username': 'jerermy29042269'},
#  {'id': 828304523718336512,
#   'name': 'Brandon Michael',
#   'username': 'TradetheAction'},
#  {'id': 1196004963882872838,
#   'name': 'BREAKOUTPLAYS',
#   'username': 'breakoutplays1'},
#  {'id': 940818526968872960, 'name': 'Flow Value', 'username': 'FlowValue'},
#  {'id': 633795759, 'name': 'Pablo CARP', 'username': 'PabloBaiocchi1'},
#  {'id': 1243457659954741248, 'name': '.', 'username': 'LxLongshort'},
#  {'id': 48440107, 'name': '4JusticeReform', 'username': '4JusticeReform'},
#  {'id': 1053364040871919616, 'name': 'PS', 'username': 'PS_81_'},
#  {'id': 2187039091, 'name': 'Vaibhaw Agrawal', 'username': 'RanchiWale'},
#  {'id': 940845757699117058,
#   'name': 'melostar.eth 🔺👁️🔺',
#   'username': 'melostar369'},
#  {'id': 1223125185210961921,
#   'name': 'Brant Hammer (Professor BTC)',
#   'username': 'CapitalNotes'},
#  {'id': 936971893734862848, 'name': 'Reez', 'username': 'reezcapital'},
#  {'id': 54729284, 'name': 'Gustavo F', 'username': 'DayTrade_'},
#  {'id': 974112183582904321, 'name': 'Edge', 'username': 'blueedged'},
#  {'id': 1241710491757666304, 'name': 'Casper', 'username': 'Cengizh89364238'},
#  {'id': 911494399510560768,
#   'name': 'Leon Moscona, MD',
#   'username': 'moscona_md'},
#  {'id': 1248371137735790592,
#   'name': 'Miko Miko',
#   'username': 'MikoMikoTrading'},
#  {'id': 353967266, 'name': 'FO-Trader', 'username': 'SrshRmynm'},
#  {'id': 1181794537510846464,
#   'name': 'Togo the Corgi',
#   'username': 'CorgiPicks'},
#  {'id': 3354700413,
#   'name': 'Investment Wisdom',
#   'username': 'investmentwisdm'},
#  {'id': 41589809, 'name': 'Jay Coulter🎙️', 'username': 'sjaycoulter'},
#  {'id': 35745774, 'name': 'Doron Raz', 'username': 'pokerwizardIL'},
#  {'id': 21328656, 'name': 'Investors.com', 'username': 'IBDinvestors'},
#  {'id': 17549691, 'name': 'NYC Trader', 'username': 'szaman'},
#  {'id': 250758475, 'name': 'Jon Boorman', 'username': 'JBoorman'},
#  {'id': 54330245, 'name': 'Nature Boy', 'username': 'Xiphos_Trading'},
#  {'id': 65681636, 'name': 'Chess', 'username': 'chessNwine'},
#  {'id': 993282182, 'name': 'Harris Market Trends', 'username': 'pharris667'},
#  {'id': 136842204, 'name': 'S. McIntyre, CMT', 'username': 'hertcapital'},
#  {'id': 242361250, 'name': 'Adam Sterling', 'username': 'adambsterling'},
#  {'id': 40129171, 'name': 'Holger Zschaepitz', 'username': 'Schuldensuehner'},
#  {'id': 497231011, 'name': 'China Beige Book', 'username': 'ChinaBeigeBook'},
#  {'id': 2030711, 'name': 'Matt Stoller', 'username': 'matthewstoller'},
#  {'id': 14792604, 'name': 'chris camp', 'username': 'christophercamp'},
#  {'id': 3074308076,
#   'name': 'Vance Barse, CPWA®, AIF®',
#   'username': 'VanceBarse'},
#  {'id': 1109642793582903296,
#   'name': 'Invariant Perspective',
#   'username': 'InvariantPersp1'},
#  {'id': 284690446, 'name': 'Stuart Slyper', 'username': 'SSlyper'},
#  {'id': 188369814,
#   'name': 'Jim Bianco biancoresearch.eth',
#   'username': 'biancoresearch'},
#  {'id': 2453385626, 'name': 'Raoul Pal', 'username': 'RaoulGMI'},
#  {'id': 2936015319, 'name': 'Luke Gromen', 'username': 'LukeGromen'},
#  {'id': 714051110, 'name': 'Sven Henrich', 'username': 'NorthmanTrader'},
#  {'id': 40273633,
#   'name': 'Reminiscences of an American Capitalist',
#   'username': '4Awesometweet'},
#  {'id': 1248952901722165248, 'name': 'philip', 'username': 'philip00330562'},
#  {'id': 3280573716,
#   'name': 'Danielle DiMartino Booth',
#   'username': 'DiMartinoBooth'},
#  {'id': 28628850, 'name': 'GregGutfeld', 'username': 'greggutfeld'},
#  {'id': 286654612, 'name': 'Dow', 'username': 'mark_dow'},
#  {'id': 1064700308,
#   'name': 'Larry Tentarelli, Blue Chip Daily',
#   'username': 'LMT978'},
#  {'id': 707591056599228417, 'name': 'Umar Ashraf', 'username': 'UmarAshraf'},
#  {'id': 288795020, 'name': 'Armann Einarsson', 'username': 'armannein'},
#  {'id': 4869241701,
#   'name': 'Rutkay Dinc, CFA, CPA',
#   'username': 'Rutkay_Dinc'},
#  {'id': 1198734555529613314,
#   'name': 'Larry Carrillo',
#   'username': 'Wolfie0516'},
#  {'id': 916153100913623045,
#   'name': 'Wild America',
#   'username': 'meditationfarm'},
#  {'id': 739539949, 'name': 'Melinda McCubbin', 'username': 'MelindaMcCubbin'},
#  {'id': 912959550608744448, 'name': 'Big Turkey 🦃', 'username': 'BigTurkey36'},
#  {'id': 1162995520228343808, 'name': 'George.P', 'username': 'GeorgePang_'},
#  {'id': 1194755106, 'name': 'Jarrod Adams', 'username': 'adamsinvesting'},
#  {'id': 898301664, 'name': 'Michael Santoli', 'username': 'michaelsantoli'},
#  {'id': 602811570, 'name': 'James DePorre', 'username': 'RevShark'},
#  {'id': 826926124512985089,
#   'name': 'David Keller, CMT',
#   'username': 'DKellerCMT'},
#  {'id': 819658450489802754,
#   'name': 'Samantha Porter',
#   'username': 'SamanthaaPort'},
#  {'id': 2335651058, 'name': 'Anmol Singh', 'username': 'DeltaNinety'},
#  {'id': 11247222, 'name': 'Timothy Sykes', 'username': 'timothysykes'},
#  {'id': 2964569193, 'name': 'Jared Wesley', 'username': 'ScalpMaster1'},
#  {'id': 193731934, 'name': 'José Paulo Lima', 'username': 'donthink2match'},
#  {'id': 15567770, 'name': 'Bridget Phetasy', 'username': 'BridgetPhetasy'},
#  {'id': 565969885, 'name': 'madaz', 'username': 'madaznfootballr'},
#  {'id': 1262364356, 'name': 'LiveStream Trading 🎙️', 'username': 'TSXtrad3r'},
#  {'id': 66746952, 'name': 'Tom Canfield', 'username': 'Canny4'},
#  {'id': 239676378, 'name': 'nextbigtrade', 'username': 'nextbigtrade'},
#  {'id': 119466953, 'name': 'Carol Roth', 'username': 'caroljsroth'},
#  {'id': 19399038, 'name': 'ForexLive', 'username': 'ForexLive'},
#  {'id': 360054369, 'name': 'Abbott', 'username': 'AbbottNews'},
#  {'id': 14117774, 'name': 'Steve Place', 'username': 'stevenplace'},
#  {'id': 2746667072, 'name': 'AT09', 'username': 'AT09_Trader'},
#  {'id': 15971805, 'name': 'Nathan Michaud', 'username': 'InvestorsLive'},
#  {'id': 235339764, 'name': 'Merritt Black', 'username': 'merrittblack'},
#  {'id': 43775786, 'name': 'Dave Portnoy', 'username': 'stoolpresidente'},
#  {'id': 253167239, 'name': 'Goldman Sachs', 'username': 'GoldmanSachs'},
#  {'id': 25787240, 'name': 'Roni J Kirchheimer', 'username': 'Attackim'},
#  {'id': 105353526, 'name': 'Mark Minervini', 'username': 'markminervini'},
#  {'id': 252751061, 'name': 'Bloomberg Quicktake', 'username': 'Quicktake'},
#  {'id': 594604675,
#   'name': 'Adam D. Koós, CFP®, CMT, CEPA',
#   'username': 'AdamKoos'},
#  {'id': 37284991, 'name': 'Urban Carmel', 'username': 'ukarlewitz'},
#  {'id': 97334517, 'name': 'J.C. Parets', 'username': 'allstarcharts'},
#  {'id': 85253884, 'name': 'Ryan Morse', 'username': 'RyanMorse33'},
#  {'id': 37065910, 'name': 'Callum Thomas', 'username': 'Callum_Thomas'},
#  {'id': 771467940168282113,
#   'name': 'Topdown Charts',
#   'username': 'topdowncharts'},
#  {'id': 983854309, 'name': 'CMT Hot 20 Countdown', 'username': 'cmtHot20'},
#  {'id': 935632100862050304,
#   'name': 'Councilmember Teresa Mosqueda',
#   'username': 'CMTMosqueda'},
#  {'id': 1176554903872954371,
#   'name': 'CMT Nashville Squares',
#   'username': 'CMTSquares'},
#  {'id': 16806253, 'name': 'Arthur Hill, CMT', 'username': 'ArthurHill'},
#  {'id': 298953617, 'name': 'Aksel Kibar, CMT', 'username': 'TechCharts'},
#  {'id': 100230006, 'name': 'Gautam Shah', 'username': 'gshah26'},
#  {'id': 22795629,
#   'name': 'After MidNite with Granger Smith',
#   'username': 'aftermidnite'},
#  {'id': 19143910, 'name': 'Douglas Busch CMT', 'username': 'chartsmarter'},
#  {'id': 160584696, 'name': 'Jonathan Krinsky,CMT', 'username': 'jkrinskypga'},
#  {'id': 34794813, 'name': 'Pat Hennessy, CMT', 'username': 'pat_hennessy'},
#  {'id': 1051421706, 'name': 'Ari Wald, CFA, CMT', 'username': 'AriWald'},
#  {'id': 19568034, 'name': 'Caroline Modarressy-Tehrani', 'username': 'CaroMT'},
#  {'id': 21232827, 'name': 'Ryan Detrick, CMT', 'username': 'RyanDetrick'},
#  {'id': 906328017986899968,
#   'name': 'Ian McMillan, CMT',
#   'username': 'the_chart_life'},
#  {'id': 1676916738,
#   'name': 'Tom Bruni, CPA, CMT',
#   'username': 'BruniCharting'},
#  {'id': 17484252, 'name': 'Michael Kahn, CMT', 'username': 'mnkahn'},
#  {'id': 407026231, 'name': 'CMT Association', 'username': 'CMTAssociation'},
#  {'id': 253168011, 'name': 'Mark Newton CMT', 'username': 'MarkNewtonCMT'},
#  {'id': 780238626345119748,
#   'name': 'Arun S. Chopra CFA CMT🧐',
#   'username': 'FusionptCapital'},
#  {'id': 24227424,
#   'name': 'Greg Harmon, CMT/CFA, President Dragonfly Capital',
#   'username': 'harmongreg'},
#  {'id': 82143051, 'name': 'GTLackeyJr CMT', 'username': 'gtlackey'},
#  {'id': 3097838351, 'name': 'Scott G, CMT', 'username': 'srgtrader'},
#  {'id': 1410125744, 'name': 'Bruce Kamich, CMT', 'username': 'BruceKamich'},
#  {'id': 1106298587581825024,
#   'name': 'Irusha Peiris, CMT',
#   'username': 'irusha'},
#  {'id': 1138836251681992707, 'name': 'Ken Rose CMT', 'username': 'KRose_TDA'},
#  {'id': 1049402231282429952,
#   'name': 'Pat Mullaly, CMT',
#   'username': 'PMullaly_TDA'},
#  {'id': 34671618,
#   'name': 'Andrew Thrasher, CMT',
#   'username': 'AndrewThrasher'},
#  {'id': 152911585, 'name': '野村證券／マーケット', 'username': 'nomura_jp'},
#  {'id': 201400755, 'name': 'iSPY Trading™', 'username': 'iSPYTrading'},
#  {'id': 2445459474,
#   'name': 'Chat With Traders',
#   'username': 'chatwithtraders'},
#  {'id': 203652149, 'name': 'Steve Burns', 'username': 'SJosephBurns'},
#  {'id': 25827743, 'name': 'Steven Spencer', 'username': 'sspencer_smb'},
#  {'id': 7520262, 'name': 'Brett Steenbarger', 'username': 'steenbab'},
#  {'id': 47087332, 'name': 'Mike Bellafiore', 'username': 'MikeBellafiore'},
#  {'id': 2232028471, 'name': 'Austin Mitchum', 'username': 'austinmitchyblu'},
#  {'id': 17790265, 'name': 'SMB Capital', 'username': 'smbcapital'},
#  {'id': 40938160, 'name': 'thinkorswim®', 'username': 'thinkorswim'},
#  {'id': 2840687505, 'name': 'Randy Frederick', 'username': 'RandyAFrederick'},
#  {'id': 26538229, 'name': 'Federal Reserve', 'username': 'federalreserve'},
#  {'id': 3449547915, 'name': 'Schwab Research', 'username': 'SchwabResearch'},
#  {'id': 16816021, 'name': 'TD Ameritrade', 'username': 'TDAmeritrade'},
#  {'id': 132703700, 'name': 'Charles Schwab Corp', 'username': 'CharlesSchwab'},
#  {'id': 25073877, 'name': 'Donald J. Trump', 'username': 'realDonaldTrump'},
#  {'id': 168679374, 'name': 'MuddyWatersResearch', 'username': 'muddywatersre'},
#  {'id': 486139568, 'name': 'Kerrisd🅰️le Capital', 'username': 'KerrisdaleCap'},
#  {'id': 2371952437,
#   'name': 'Spruce Point Capital',
#   'username': 'sprucepointcap'},
#  {'id': 1327359720, 'name': 'Lisa Abramowicz', 'username': 'lisaabramowicz1'},
#  {'id': 320524842, 'name': 'Jesse Colombo', 'username': 'TheBubbleBubble'},
#  {'id': 15246621, 'name': 'Brian Shannon, CMT', 'username': 'alphatrends'},
#  {'id': 404422077, 'name': 'Squawk Box', 'username': 'SquawkCNBC'},
#  {'id': 624413, 'name': 'MarketWatch', 'username': 'MarketWatch'},
#  {'id': 26574283, 'name': 'CNBC Now', 'username': 'CNBCnow'},
#  {'id': 15281391, 'name': 'TheStreet', 'username': 'TheStreet'},
#  {'id': 106498703, 'name': 'Squawk on the Street', 'username': 'SquawkStreet'},
#  {'id': 20402945, 'name': 'CNBC', 'username': 'CNBC'},
#  {'id': 69620713, 'name': 'Bloomberg Markets', 'username': 'markets'},
#  {'id': 16732770, 'name': "CNBC's Fast Money", 'username': 'CNBCFastMoney'},
#  {'id': 14216123, 'name': 'Jim Cramer', 'username': 'jimcramer'},
#  {'id': 16451932, 'name': 'Mad Money On CNBC', 'username': 'MadMoneyOnCNBC'},
#  {'id': 430841130, 'name': 'CtheLightTrading', 'username': 'canuck2usa'},
#  {'id': 201891203, 'name': 'SangLucci™', 'username': 'sanglucci'},
#  {'id': 61342056, 'name': 'Joe Kunkle', 'username': 'OptionsHawk'},
#  {'id': 475524030, 'name': 'JE$US', 'username': 'WallStJesus'},
#  {'id': 2827242385, 'name': '∆ Desk Report', 'username': 'Delta_Desk'},
#  {'id': 1296952741, 'name': 'RB Trader', 'username': 'rb_trader'},
#  {'id': 2552639978, 'name': 'Traders4ACause', 'username': 'Traders4ACause'},
#  {'id': 2409330439, 'name': 'THE Trading Fish', 'username': 'mrockrulez'},
#  {'id': 14456478, 'name': 'Sheryl Ramer', 'username': 'PodcastLib'},
#  {'id': 717137706, 'name': 'erick berreondo', 'username': 'EBBistro'},
#  {'id': 18120133, 'name': 'Sic Figures Trading', 'username': 'coreykindhart'},
#  {'id': 96682182, 'name': 'Modern_Rock', 'username': 'modern_rock'},
#  {'id': 18999708, 'name': 'CBC Business', 'username': 'CBCBusiness'},
#  {'id': 30041336, 'name': 'Rob Carrick', 'username': 'rcarrick'},
#  {'id': 48752324, 'name': 'MoneySense', 'username': 'MoneySense'},
#  {'id': 3108351, 'name': 'The Wall Street Journal', 'username': 'WSJ'},
#  {'id': 109350515, 'name': 'BNN Bloomberg', 'username': 'BNNBloomberg'},
#  {'id': 17826999, 'name': 'Globe Investor', 'username': 'globeinvestor'},
#  {'id': 20562637, 'name': 'Business Insider', 'username': 'BusinessInsider'},
#  {'id': 18921643, 'name': 'Canadian Business', 'username': 'cdnbiz'},
#  {'id': 25561260, 'name': 'FP Investing', 'username': 'fpinvesting'},
#  {'id': 5988062, 'name': 'The Economist', 'username': 'TheEconomist'},
#  {'id': 16364684, 'name': 'Finance Canada', 'username': 'FinanceCanada'},
#  {'id': 14980721, 'name': 'Bank of Canada', 'username': 'bankofcanada'},
#  {'id': 22631935, 'name': 'Canada Business', 'username': 'canadabusiness'},
#  {'id': 21619519, 'name': 'Joe Scarborough', 'username': 'JoeNBC'},
#  {'id': 102481836,
#   'name': 'Yahoo Finance Canada',
#   'username': 'YahooFinanceCA'},
#  {'id': 14800270, 'name': 'Harvard Business Review', 'username': 'HarvardBiz'},
#  {'id': 3329528134, 'name': "IBKR Traders' Insight", 'username': 'IBKR_TI'},
#  {'id': 210824456,
#   'name': 'Canada Revenue Agency',
#   'username': 'CanRevAgency'},
#  {'id': 323396034, 'name': 'Traders Magazine', 'username': 'traders_tweets'},
#  {'id': 85523269, 'name': 'Garth Mackenzie', 'username': 'TradersCorner'}]

# %%
twitter = {
    "username":usersnames,
    "id":twitter_id,
    "name":twitter_name
}
twitter_users= pd.DataFrame(twitter)

# %%
columns = set()
allowed_types = [str, int]
tweets_data = []
for status in timeline_list[0]:
    print(status)
    status_dict = dict(status)
    keys = status_dict.keys()
    single_tweet_data = {{"user": status.user.screen_name, "author": status.author.screen_name}}
    for k in keys:
        try:
            v_type = type(status_dict[k])
        except:
            v_type = None
        if v_type != None:
            if v_type in allowed_types:
                single_tweet_data[k] = status_dict[k]
                columns.add(k)
    tweets_data.append(single_tweet_data)


header_cols = list(columns)
header_cols.append("user")
header_cols.append('author')
df = pd.DataFrame(tweets_data, columns=header_cols)


header_cols = list(columns)
header_cols.append("user")
header_cols.append('author')
df = pd.DataFrame(tweets_data, columns=header_cols)
# Out:
# [<Tweet id=1599979447980986370 text='RT @alexhern: seems legit https://t.co/mGysyzt3W1'>, <Tweet id=1599577572643258369 text='@NicoleBarbaro This graph is terrible from a comms perspective.'>, <Tweet id=1599554972827295744 text='@DRouselle Mostly referring to the recent Munk debate but I understand that some people feel this way about some of his books.'>, <Tweet id=1599463849849425921 text='RT @IonaItalia: God, I used to be such a dickhead in the past. Present me feels some fremdschaemen on behalf of past me. Well, I guess that…'>, <Tweet id=1599462791047364608 text='@RuxandraTeslo Scary Rux!'>, <Tweet id=1599189538127028225 text='@SexyIsntSexist Look up Dean Potter (Climber/BaseJumper) I think he could be on the list. Love the guy but clearly he always wanted to push further.'>, <Tweet id=1599062149808066562 text='@FemcomSiham I was more thinking about western school but you make a good point!'>, <Tweet id=1599050184117301248 text='I wonder how think might change/ or not with gender separated schooling. https://t.co/PQQ4cOyFVV'>, <Tweet id=1599043846662287360 text='@Britonomist Do people deny this? It seem so blatantly obvious.'>, <Tweet id=1599043235199930368 text='@RuxandraTeslo @AliceFromQueens But is he as well dressed?'>, <Tweet id=1599041825095835648 text='@RuxandraTeslo I wanna know, what this New Age genre is?'>, <Tweet id=1599033142601744385 text='I thought I liked Malcom Gladwell, but what a dishonest guy.'>, <Tweet id=1599001433273438208 text='@doc_bcytnt I mean I actually would like to attend this 😕'>, <Tweet id=1598854126619676672 text='@ryancbriggs I thoughts it was a chromosome until I read the caption.'>, <Tweet id=1598834441232973824 text='@RuxandraTeslo How many languages do you speak?'>, <Tweet id=1598336285126574082 text='Open-access peer reviewed journal are amazing for readers, but so damn expensive for the author making it a not so attractive thing to do. Real shame.'>, <Tweet id=1597975022001233920 text='Possibly JJs worst take. https://t.co/fxvth7KiWX'>, <Tweet id=1597971506600239104 text='@FrenchHist It’s more (proto) German/Norse that makes no sense with superficial French for fancy words and the elite.'>, <Tweet id=1597970204918616065 text='@phl43 Other than the basics everything very underdetermined in nutrition science.'>, <Tweet id=1597969011652055040 text='@datepsych In my undergrad most people attended lectures but I always knew a few who would only read the textbook and do well in the course. I wonder, what percentage of the class will pass?'>, <Tweet id=1597687507189395456 text='@datepsych I’ve been a few class where the profs just completely deny the use of IQ. Usually they are Gardner supporters.'>, <Tweet id=1597682628685012992 text="RT @phl43: It's a great book that very accurately describes how science works in practice and is well worth reading, but unfortunately it o…">, <Tweet id=1597594075850760195 text='@RuxandraTeslo @man_ditch @olivertraldi @BeaLeydier @basedball_ I disappointed in the lack of questions.'>, <Tweet id=1597271997985456129 text='Be high prestige like @datepsych. https://t.co/D8rnTf3x6M'>, <Tweet id=1597207060961062912 text='@lastpositivist “French rioting over anything” truly the best culture.'>, <Tweet id=1597100589116112896 text='RT @jonathanstea: One way to experience intellectual growth is to let go of treasured beliefs in the face of overwhelming counter-evidence.'>, <Tweet id=1597098838652657665 text='Idk, but my bones says this is anti-liberalism. https://t.co/4KRLg0Ojdr'>, <Tweet id=1596962581687640064 text='@MatousPikous @araknofennisti @AstroVicnet @YatimaOfKonishi @Deanzsyclone @YTurtle247 @thunderf00t I agree, we shouldn’t believe his claim without evidence of his competency.'>, <Tweet id=1596952233144614913 text='@araknofennisti @AstroVicnet @YatimaOfKonishi @Deanzsyclone @YTurtle247 @thunderf00t A credential doesn’t make you magically good at something, expertise and practice do. Credentials just act as a heuristic for expertise and practice but it’s  ...
# {}
# []
# {'next_token': '7140dibdnow9c7btw423wwlxt4jbhibyfd4edad6o46cy', 'result_count': 99, 'newest_id': '1599979447980986370', 'oldest_id': '1582372617461256192'}

# %%
for status in timeline_list[0]:
    print(dict(status))
len(timeline_list[0])
# Out:
# {'edit_history_tweet_ids': [1599979447980986370], 'id': 1599979447980986370, 'text': 'RT @alexhern: seems legit https://t.co/mGysyzt3W1'}
# {'edit_history_tweet_ids': [1599577572643258369], 'id': 1599577572643258369, 'text': '@NicoleBarbaro This graph is terrible from a comms perspective.'}
# {'edit_history_tweet_ids': [1599554972827295744], 'id': 1599554972827295744, 'text': '@DRouselle Mostly referring to the recent Munk debate but I understand that some people feel this way about some of his books.'}
# {'edit_history_tweet_ids': [1599463849849425921], 'id': 1599463849849425921, 'text': 'RT @IonaItalia: God, I used to be such a dickhead in the past. Present me feels some fremdschaemen on behalf of past me. Well, I guess that…'}
# {'edit_history_tweet_ids': [1599462791047364608], 'id': 1599462791047364608, 'text': '@RuxandraTeslo Scary Rux!'}
# {'edit_history_tweet_ids': [1599189538127028225], 'id': 1599189538127028225, 'text': '@SexyIsntSexist Look up Dean Potter (Climber/BaseJumper) I think he could be on the list. Love the guy but clearly he always wanted to push further.'}
# {'edit_history_tweet_ids': [1599062149808066562], 'id': 1599062149808066562, 'text': '@FemcomSiham I was more thinking about western school but you make a good point!'}
# {'edit_history_tweet_ids': [1599050184117301248], 'id': 1599050184117301248, 'text': 'I wonder how think might change/ or not with gender separated schooling. https://t.co/PQQ4cOyFVV'}
# {'edit_history_tweet_ids': [1599043846662287360], 'id': 1599043846662287360, 'text': '@Britonomist Do people deny this? It seem so blatantly obvious.'}
# {'edit_history_tweet_ids': [1599043235199930368], 'id': 1599043235199930368, 'text': '@RuxandraTeslo @AliceFromQueens But is he as well dressed?'}
# {'edit_history_tweet_ids': [1599041825095835648], 'id': 1599041825095835648, 'text': '@RuxandraTeslo I wanna know, what this New Age genre is?'}
# {'edit_history_tweet_ids': [1599033142601744385], 'id': 1599033142601744385, 'text': 'I thought I liked Malcom Gladwell, but what a dishonest guy.'}
# {'edit_history_tweet_ids': [1599001433273438208], 'id': 1599001433273438208, 'text': '@doc_bcytnt I mean I actually would like to attend this 😕'}
# {'edit_history_tweet_ids': [1598854126619676672], 'id': 1598854126619676672, 'text': '@ryancbriggs I thoughts it was a chromosome until I read the caption.'}
# {'edit_history_tweet_ids': [1598834441232973824], 'id': 1598834441232973824, 'text': '@RuxandraTeslo How many languages do you speak?'}
# {'edit_history_tweet_ids': [1598336285126574082], 'id': 1598336285126574082, 'text': 'Open-access peer reviewed journal are amazing for readers, but so damn expensive for the author making it a not so attractive thing to do. Real shame.'}
# {'edit_history_tweet_ids': [1597975022001233920], 'id': 1597975022001233920, 'text': 'Possibly JJs worst take. https://t.co/fxvth7KiWX'}
# {'edit_history_tweet_ids': [1597971506600239104], 'id': 1597971506600239104, 'text': '@FrenchHist It’s more (proto) German/Norse that makes no sense with superficial French for fancy words and the elite.'}
# {'edit_history_tweet_ids': [1597970204918616065], 'id': 1597970204918616065, 'text': '@phl43 Other than the basics everything very underdetermined in nutrition science.'}
# {'edit_history_tweet_ids': [1597969011652055040], 'id': 1597969011652055040, 'text': '@datepsych In my undergrad most people attended lectures but I always knew a few who would only read the textbook and do well in the course. I wonder, what percentage of the class will pass?'}
# {'edit_history_tweet_ids': [1597687507189395456], 'id': 1597687507189395456, 'text': '@datepsych I’ve been a few class where the profs just completely deny the use of IQ. Usually they are Gardner supporters.'}
# {'edit_history_tweet_ids': [1597682628685012992], 'id': 1597682628685012992, 'text': "RT @phl43: It's a great book that very accurately describes how science works in practice and is well worth reading, but unfortunately it o…"}
# {'edit_history_tweet_ids': [1597594075850760195], 'id': 1597594075850760195, 'text': '@RuxandraTeslo @man_ditch @olivertraldi @BeaLeydier @basedball_ I disappointed in the lack of questions.'}
# {'edit_history_tweet_ids': [1597271997985456129], 'id': 1597271997985456129, 'text': 'Be high prestige like @datepsych. https://t.co/D8rnTf3x6M'}
# {'edit_history_tweet_ids': [1597207060961062912], 'id': 1597207060961062912, 'text': '@lastpositivist “French rioting over anything” truly the best culture.'}
# {'edit_history_tweet_ids': [1597100589116112896], 'id': 1597100589116112896, 'text': 'RT @jonathanstea: One way to experience intellectual growth is to let go of treasured beliefs in the face of overwhelming counter-evidence.'}
# {'edit_history_tweet_ids': [1597098838652657665], 'id': 1597098838652657665, 'text': 'Idk, but my bones says this is anti-liberalism. https://t.co/4KRLg0Ojdr'}
# {'edit_history_tweet_ids': [1596962581687640064], 'id': 1596962581687640064, 'text': '@MatousPikous @araknofennisti @AstroVicnet @YatimaOfKonishi @Deanzsyclone @YTurtle247 @thunderf00t I agree, we shouldn’t believe his claim without evidence of his competency.'}
# {'edit_history_tweet_ids': [1596952233144614913], 'id': 1596952233144614913, 'text': '@araknofennisti @AstroVicnet @YatimaOfKonishi @Deanzsyclone @YTurtle247 @thunderf00t A credential doesn’t make you magically good at something, expertise and practice do. Credentials just act as a heuristic for expertise and practice but it’s still flawed argument.'}
# {'edit_history_tweet_ids': [1596951057988718593], 'id': 1596951057988718593, 'text': '@mshiltonj @AstroVicnet @YatimaOfKonishi @Deanzsyclone @YTurtle247 @thunderf00t I agree with thunderf00t I just think this is a dishonest criticism.'}
# {'edit_history_tweet_ids': [1596947871521472512], 'id': 1596947871521472512, 'text': '@AstroVicnet @YatimaOfKonishi @Deanzsyclone @YTurtle247 @thunderf00t I mean this is just credentialism. I don’t think /know if Musk is a good engineer but this is just a flawed rebuttal.'}
# {'edit_history_tweet_ids': [1596938630890934272], 'id': 1596938630890934272, 'text': 'RT @LRGpod: Our next guest is @cp_cheung! Christian is a researcher in the Human Performance and Health Research Lab at the University of G…'}
# {'edit_history_tweet_ids': [1596938140442562560], 'id': 1596938140442562560, 'text': 'If you spell colour without a “u” you are wrong.'}
# {'edit_history_tweet_ids': [1596732731689664512], 'id': 1596732731689664512, 'text': 'RT @NicoleBarbaro: IN MICE'}
# {'edit_history_tweet_ids': [1596655201879924736], 'id': 1596655201879924736, 'text': 'RT @nickchk: In statistics, measurement is hard. Comparing two measurements is twice as hard. Comparing two comparisons is twice as hard ag…'}
# {'edit_history_tweet_ids': [1596562743423008768], 'id': 1596562743423008768, 'text': '@NicoleBarbaro Generally agree. PowerPoint is mostly for presenting. Creating actual written handouts to go with the ppts is probably the way to go.'}
# {'edit_history_tweet_ids': [1596561218126454785], 'id': 1596561218126454785, 'text': '@RuxandraTeslo I think it serves a similar function but I also think podcasts can be valid in their own right. They just serve a different purpose and audience.'}
# {'edit_history_tweet_ids': [1596554669320544257], 'id': 1596554669320544257, 'text': '@RuxandraTeslo There are plenty of fiction based podcasts so I don’t fully understand.'}
# {'edit_history_tweet_ids': [1596518146030161922], 'id': 1596518146030161922, 'text': 'You may not like it but this is what peek performance looks like. https://t.co/pEDpOnBkpr'}
# {'edit_history_tweet_ids': [1596502691022311426], 'id': 1596502691022311426, 'text': '@theatlaspro Personally I like editing, but 99% of making something is just research and writing lol.'}
# {'edit_history_tweet_ids': [1596274560009396226], 'id': 1596274560009396226, 'text': 'RT @mealreplacer: social science is so cool, I wish it was real'}
# {'edit_history_tweet_ids': [1596142339172728838], 'id': 1596142339172728838, 'text': 'RT @FossilHistory: Charles Darwin’s Origin of Species was published #OnThisDay in 1859. “There is grandeur in this view of life - that from…'}
# {'edit_history_tweet_ids': [1595991488650887169], 'id': 1595991488650887169, 'text': '@DerekPederson3 @clairlemon I’ll miss Sam, I may not agree with everything he said but he is someone I had listened too for a long time and one of my first follows on this site. Sad to see Claire leave too.'}
# {'edit_history_tweet_ids': [1595989555584577536], 'id': 1595989555584577536, 'text': '@DoctorLockwood Seems so, sadly.'}
# {'edit_history_tweet_ids': [1595542589201158145], 'id': 1595542589201158145, 'text': 'RT @datepsych: Imagine you have a small population to study - just 3 monkeys.\n\nYou want to know if there is a relationship between two vari…'}
# {'edit_history_tweet_ids': [1595443886855528449], 'id': 1595443886855528449, 'text': '@justin_garson @PsychToday In my mind ADHA works a lot like sociopathy, advantageous up to a point at which it becomes deleterious. The big difference being that group selection works against sociopathy and it sticks around due the benefits to individuals. I don’t think that’s the case for ADHD.'}
# {'edit_history_tweet_ids': [1595412636966985729], 'id': 1595412636966985729, 'text': 'RT @datepsych: The importance of cleaning your data. Revise spreadsheets for errors, typos, weird artifacts of the program.\n\nA lot of error…'}
# {'edit_history_tweet_ids': [1595125855252271105], 'id': 1595125855252271105, 'text': 'The conversation here is interesting. That being said I’m going to stick with fish 🐠 https://t.co/tf1QYy3GtR'}
# {'edit_history_tweet_ids': [1595100064971911168], 'id': 1595100064971911168, 'text': '@RuxandraTeslo Cancer and Capybara both start with the letter C.'}
# {'edit_history_tweet_ids': [1595090403518468096], 'id': 1595090403518468096, 'text': '@RuxandraTeslo The only reason is for fun.'}
# {'edit_history_tweet_ids': [1595088204931411968], 'id': 1595088204931411968, 'text': '@datepsych I wonder what might be the cause of this.'}
# {'edit_history_tweet_ids': [1594857835267256320], 'id': 1594857835267256320, 'text': 'RT @StuartJRitchie: V pleased to have a piece in the first issue of @asteriskmgzn! It’s on whether the Replication Crisis “worked”. Sure, w…'}
# {'edit_history_tweet_ids': [1594743575719600128], 'id': 1594743575719600128, 'text': 'RT @njoybetz: Academia does not have a monopoly on science, nor the creation of knowledge.\n\nThese things can and do successfully take place…'}
# {'edit_history_tweet_ids': [1594740478779723781], 'id': 1594740478779723781, 'text': '@PalaeoPhilo You couldn’t make your life look any less dangerous.'}
# {'edit_history_tweet_ids': [1594704874578792450], 'id': 1594704874578792450, 'text': '@FrenchHist Food, Culture, and Language.'}
# {'edit_history_tweet_ids': [1594368932496183296], 'id': 1594368932496183296, 'text': 'RT @samthielman: Oh boy, $150,000! https://t.co/Xn81HiPd8I'}
# {'edit_history_tweet_ids': [1594013844346900480], 'id': 1594013844346900480, 'text': '@katiedimartin @DerekPederson3 Quebec would be in an uproar.'}
# {'edit_history_tweet_ids': [1594013499902300162], 'id': 1594013499902300162, 'text': '@DerekPederson3 As a French Canadian I’m not Latino.'}
# {'edit_history_tweet_ids': [1593701806621982720], 'id': 1593701806621982720, 'text': '@RuxandraTeslo When you find out send me a link.'}
# {'edit_history_tweet_ids': [1593677751546150912], 'id': 1593677751546150912, 'text': '@HKBradshaw @CostelloWilliam https://t.co/6Dk761MiL2'}
# {'edit_history_tweet_ids': [1593674824995713025], 'id': 1593674824995713025, 'text': '@HKBradshaw This one is easily my favorite'}
# {'edit_history_tweet_ids': [1593674536423403520], 'id': 1593674536423403520, 'text': 'RT @HKBradshaw: having students create content for me https://t.co/GlLwvQR9sX'}
# {'edit_history_tweet_ids': [1592699779926347778], 'id': 1592699779926347778, 'text': 'This is going to be an interesting year for @LUSciComm students to learn social media skills. Twitter seems to be changing quickly.'}
# {'edit_history_tweet_ids': [1592346671673139200], 'id': 1592346671673139200, 'text': 'My love of evolution keeps on leading me to weird places. Recently I’ve been coding a lot and now I want to leaner evolutionary algorithms.'}
# {'edit_history_tweet_ids': [1591970874340814849], 'id': 1591970874340814849, 'text': '@nickchk Banger tweet.'}
# {'edit_history_tweet_ids': [1591817250935562241], 'id': 1591817250935562241, 'text': '@datepsych This sadly doesn’t surprise me. Best to just eat your fruit and veg and move on.'}
# {'edit_history_tweet_ids': [1589604616970588162], 'id': 1589604616970588162, 'text': "RT @glenpyle: You'd think #cannabis would have a relaxing effect on the heart, but you'd be wrong.\n\nSome really interesting work at #AHA202…"}
# {'edit_history_tweet_ids': [1589585718107844609], 'id': 1589585718107844609, 'text': 'RT @AnthonyLeeZhang: With the bimodal distribution, IMO the right strategy is to make clear which parts of the talk are designed for who. M…'}
# {'edit_history_tweet_ids': [1589276924618031104], 'id': 1589276924618031104, 'text': 'Monday: I want to do a PhD\nTuesday: I want money and a life\nWednesday: Fuck it, I want a PhD\nThursday: I can’t, let me make money\nFriday: I can’t do either… I’m going to sleep for the weekend.\nRepeat.'}
# {'edit_history_tweet_ids': [1589041666383831040], 'id': 1589041666383831040, 'text': 'I hate reading my old tweets and realizing the number of typos I make.'}
# {'edit_history_tweet_ids': [1588727190296100864], 'id': 1588727190296100864, 'text': 'RT @morozov_dev: When your code works, but you have no idea how https://t.co/zNKc0C6pyy'}
# {'edit_history_tweet_ids': [1588710785433276421], 'id': 1588710785433276421, 'text': '@DerekPederson3 I can understand your what you mean, atleast for some of the recent tweets.'}
# {'edit_history_tweet_ids': [1588708398698467329], 'id': 1588708398698467329, 'text': '@DrJacobsRad I personally thing they should be able to strike. But I also understand that this is a bad situation for many.'}
# {'edit_history_tweet_ids': [1588708035454971906], 'id': 1588708035454971906, 'text': '@DerekPederson3 Not sure I agree with Soh but honestly haven’t kept up with her in a while. I would put Peterson in his own category as well.'}
# {'edit_history_tweet_ids': [1588508181466316801], 'id': 1588508181466316801, 'text': '@RuxandraTeslo I feel like all the dinosaur kids went into bio then realized there were other fields. They never stopped being dino-kids. Sample size of me.'}
# {'edit_history_tweet_ids': [1588507551364419585], 'id': 1588507551364419585, 'text': '@GEdwardsTwit Just as I’m learning to code… this damn market moves too quickly.'}
# {'edit_history_tweet_ids': [1588506792706789377], 'id': 1588506792706789377, 'text': 'Why is it the more educated I guess the less I respect credentialism?'}
# {'edit_history_tweet_ids': [1588506117050884096], 'id': 1588506117050884096, 'text': 'RT @Britonomist: Academics not being open to scrutiny or accountability from ‘outsiders’ 🚩🚩🚩🚩🚩🚩🚩🚩🚩🚩🚩🚩🚩'}
# {'edit_history_tweet_ids': [1588368531837849600], 'id': 1588368531837849600, 'text': 'Actually don’t look into this. It only get worse…'}
# {'edit_history_tweet_ids': [1588367050958770176], 'id': 1588367050958770176, 'text': 'I really hate when sources don’t lead anywhere but a Twitter account 🤦\u200d♂️ https://t.co/HkgStldyt8'}
# {'edit_history_tweet_ids': [1588142679631839234], 'id': 1588142679631839234, 'text': '@BeaLeydier Now combine the two together and you have Canada.'}
# {'edit_history_tweet_ids': [1588138534942253056], 'id': 1588138534942253056, 'text': '@ewinsberg Finally working on the important questions!'}
# {'edit_history_tweet_ids': [1587592816380854275], 'id': 1587592816380854275, 'text': 'RT @LongFormMath: I appreciate the honesty https://t.co/rWrSulBFeC'}
# {'edit_history_tweet_ids': [1587132135458095104], 'id': 1587132135458095104, 'text': 'RT @lastpositivist: @bayesianboy Not so, you just have to intersperse little parenthetical remarks being like "(which is bad, by the way)"…'}
# {'edit_history_tweet_ids': [1586933171320504321], 'id': 1586933171320504321, 'text': '@DerekPederson3 @NoamKissinger @brutal_veracity “I’m not the type of atheist to convince others” woah, idk how to even react to that.'}
# {'edit_history_tweet_ids': [1586920467209805824], 'id': 1586920467209805824, 'text': '@SteveStuWill And there is the Twitter phylogeny lesson of the day.'}
# {'edit_history_tweet_ids': [1586480933301018626], 'id': 1586480933301018626, 'text': '@xavierbonilla87 @NicoleBarbaro RIP to brave books that don’t make it.'}
# {'edit_history_tweet_ids': [1586026337612996611], 'id': 1586026337612996611, 'text': '@crocoduck_king Debate @lastpositivist on standpoint theory.'}
# {'edit_history_tweet_ids': [1585818713160384512], 'id': 1585818713160384512, 'text': 'RT @austinlwright: Abstract                        Paper https://t.co/LrDQRLBF2i'}
# {'edit_history_tweet_ids': [1585815544703639552], 'id': 1585815544703639552, 'text': 'RT @NicoleBarbaro: Evolutionary theory, though not accounting for everything, is IMO one of the best paths forward for psychology to break…'}
# {'edit_history_tweet_ids': [1585815145485598722], 'id': 1585815145485598722, 'text': 'Dog sitting mine become my new hobby. https://t.co/ps6w2aIldy'}
# {'edit_history_tweet_ids': [1585438390438268934], 'id': 1585438390438268934, 'text': '@Friended4Ever Yikes 😬😬'}
# {'edit_history_tweet_ids': [1585378280580222976], 'id': 1585378280580222976, 'text': '@RuxandraTeslo @lastpositivist Isn’t that why we are centrist?!'}
# {'edit_history_tweet_ids': [1584169808677175296], 'id': 1584169808677175296, 'text': '@phl43 @RuxandraTeslo Infinite knowledge is her goal, we better watch out.'}
# {'edit_history_tweet_ids': [1583821635928268800], 'id': 1583821635928268800, 'text': '@ProfDavidBuss @CostelloWilliam Much appreciated'}
# {'edit_history_tweet_ids': [1583820877430370305], 'id': 1583820877430370305, 'text': '@powerm1985 When Pathos become the rhetoric of choice of a paper, you know you’re in a bad spot.'}
# {'edit_history_tweet_ids': [1583161487056859136], 'id': 1583161487056859136, 'text': '@RuxandraTeslo Chaotic good is just the vibe you give me.'}
# {'edit_history_tweet_ids': [1582373514992320514], 'id': 1582373514992320514, 'text': '@primalpoly @hcetamd I think this shows your followers are pretty much on the mark.'}
# {'edit_history_tweet_ids': [1582372617461256192], 'id': 1582372617461256192, 'text': 'Last week I spent a few hours making a spreadsheet to track how many of my book I’ve read. Currently, I’ve read 43% of them.'}
# 99

# %%
def extract_timeline_as_df(timeline_list):
    columns = set()
    allowed_types = [str, int]
    tweets_data = []
    for status in timeline_list[0]:
        status_dict = dict(status)
        keys = status_dict.keys()
        single_tweet_data = {"username": timeline_list[1]['users'][0]["username"]}
        for k in keys:
            try:
                v_type = type(status_dict[k])
            except:
                v_type = None
            if v_type != None:
                if v_type in allowed_types:
                    single_tweet_data[k] = status_dict[k]
                    columns.add(k)
        tweets_data.append(single_tweet_data)


    header_cols = list(columns)
    header_cols.append("username")
    header_cols.append('author')
    df = pd.DataFrame(tweets_data, columns=header_cols)


    header_cols = list(columns)
    header_cols.append("username")
    
    df = pd.DataFrame(tweets_data, columns=header_cols)
    return df

# %%
for user in username:
    
    user = api.get_user(str(user))

# %%
timeline_list = client.get_users_tweets('1443048757721972737',start_time = '2021-12-07T00:28:41+00:00',max_results=100,expansions='author_id', tweet_fields='created_at')
# df1 = extract_timeline_as_df(user_timeline)
# df1.head()
timeline_list
# Out:
# Response(data=[<Tweet id=1599979447980986370 text='RT @alexhern: seems legit https://t.co/mGysyzt3W1'>, <Tweet id=1599577572643258369 text='@NicoleBarbaro This graph is terrible from a comms perspective.'>, <Tweet id=1599554972827295744 text='@DRouselle Mostly referring to the recent Munk debate but I understand that some people feel this way about some of his books.'>, <Tweet id=1599463849849425921 text='RT @IonaItalia: God, I used to be such a dickhead in the past. Present me feels some fremdschaemen on behalf of past me. Well, I guess that…'>, <Tweet id=1599462791047364608 text='@RuxandraTeslo Scary Rux!'>, <Tweet id=1599189538127028225 text='@SexyIsntSexist Look up Dean Potter (Climber/BaseJumper) I think he could be on the list. Love the guy but clearly he always wanted to push further.'>, <Tweet id=1599062149808066562 text='@FemcomSiham I was more thinking about western school but you make a good point!'>, <Tweet id=1599050184117301248 text='I wonder how think might change/ or not with gender separated schooling. https://t.co/PQQ4cOyFVV'>, <Tweet id=1599043846662287360 text='@Britonomist Do people deny this? It seem so blatantly obvious.'>, <Tweet id=1599043235199930368 text='@RuxandraTeslo @AliceFromQueens But is he as well dressed?'>, <Tweet id=1599041825095835648 text='@RuxandraTeslo I wanna know, what this New Age genre is?'>, <Tweet id=1599033142601744385 text='I thought I liked Malcom Gladwell, but what a dishonest guy.'>, <Tweet id=1599001433273438208 text='@doc_bcytnt I mean I actually would like to attend this 😕'>, <Tweet id=1598854126619676672 text='@ryancbriggs I thoughts it was a chromosome until I read the caption.'>, <Tweet id=1598834441232973824 text='@RuxandraTeslo How many languages do you speak?'>, <Tweet id=1598336285126574082 text='Open-access peer reviewed journal are amazing for readers, but so damn expensive for the author making it a not so attractive thing to do. Real shame.'>, <Tweet id=1597975022001233920 text='Possibly JJs worst take. https://t.co/fxvth7KiWX'>, <Tweet id=1597971506600239104 text='@FrenchHist It’s more (proto) German/Norse that makes no sense with superficial French for fancy words and the elite.'>, <Tweet id=1597970204918616065 text='@phl43 Other than the basics everything very underdetermined in nutrition science.'>, <Tweet id=1597969011652055040 text='@datepsych In my undergrad most people attended lectures but I always knew a few who would only read the textbook and do well in the course. I wonder, what percentage of the class will pass?'>, <Tweet id=1597687507189395456 text='@datepsych I’ve been a few class where the profs just completely deny the use of IQ. Usually they are Gardner supporters.'>, <Tweet id=1597682628685012992 text="RT @phl43: It's a great book that very accurately describes how science works in practice and is well worth reading, but unfortunately it o…">, <Tweet id=1597594075850760195 text='@RuxandraTeslo @man_ditch @olivertraldi @BeaLeydier @basedball_ I disappointed in the lack of questions.'>, <Tweet id=1597271997985456129 text='Be high prestige like @datepsych. https://t.co/D8rnTf3x6M'>, <Tweet id=1597207060961062912 text='@lastpositivist “French rioting over anything” truly the best culture.'>, <Tweet id=1597100589116112896 text='RT @jonathanstea: One way to experience intellectual growth is to let go of treasured beliefs in the face of overwhelming counter-evidence.'>, <Tweet id=1597098838652657665 text='Idk, but my bones says this is anti-liberalism. https://t.co/4KRLg0Ojdr'>, <Tweet id=1596962581687640064 text='@MatousPikous @araknofennisti @AstroVicnet @YatimaOfKonishi @Deanzsyclone @YTurtle247 @thunderf00t I agree, we shouldn’t believe his claim without evidence of his competency.'>, <Tweet id=1596952233144614913 text='@araknofennisti @AstroVicnet @YatimaOfKonishi @Deanzsyclone @YTurtle247 @thunderf00t A credential doesn’t make you magically good at something, expertise and practice do. Credentials just act as a heuristic for expertise and prac ...

# %%
timeline_list[1]['users'][0]['username']
# Out:
# 'DavidScienceCom'

# %%
id = 1599979447980986370
client.

# %%
df_david=extract_timeline_as_df(timeline_list)
df_david[["id"]]
# Out:
#                      id
# 0   1599979447980986370
# 1   1599577572643258369
# 2   1599554972827295744
# 3   1599463849849425921
# 4   1599462791047364608
# ..                  ...
# 94  1583821635928268800
# 95  1583820877430370305
# 96  1583161487056859136
# 97  1582373514992320514
# 98  1582372617461256192
#
# [99 rows x 1 columns]

# %%
df_david.drop("id",axis=1)

# %%
df_david= extract_timeline_as_df(timeline_list)
twitter_users.merge(df_david, how = 'outer', on = 'username')
# Out:
#             username                 id_x                     name  \
# 0    DavidScienceCom  1443048757721972737                    David
# 1    DavidScienceCom  1443048757721972737                    David
# 2    DavidScienceCom  1443048757721972737                    David
# 3    DavidScienceCom  1443048757721972737                    David
# 4    DavidScienceCom  1443048757721972737                    David
# ..               ...                  ...                      ...
# 988       HarvardBiz             14800270  Harvard Business Review
# 989          IBKR_TI           3329528134    IBKR Traders' Insight
# 990     CanRevAgency            210824456    Canada Revenue Agency
# 991   traders_tweets            323396034         Traders Magazine
# 992    TradersCorner             85523269          Garth Mackenzie
#
#                                                   text          id_y  \
# 0    RT @alexhern: seems legit https://t.co/mGysyzt3W1  1.599979e+18
# 1    @NicoleBarbaro This graph is terrible from a c...  1.599578e+18
# 2    @DRouselle Mostly referring to the recent Munk...  1.599555e+18
# 3    RT @IonaItalia: God, I used to be such a dickh...  1.599464e+18
# 4                            @RuxandraTeslo Scary Rux!  1.599463e+18
# ..                                                 ...           ...
# 988                                                NaN           NaN
# 989                                                NaN           NaN
# 990                                                NaN           NaN
# 991                                                NaN           NaN
# 992                                                NaN           NaN
#
#         author_id
# 0    1.443049e+18
# 1    1.443049e+18
# 2    1.443049e+18
# 3    1.443049e+18
# 4    1.443049e+18
# ..            ...
# 988           NaN
# 989           NaN
# 990           NaN
# 991           NaN
# 992           NaN
#
# [993 rows x 6 columns]

# %%
columns = set()

for user in response[0][0]:
#     print(user)
    keys = vars(user).keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28216\3014159901.py in <module>
#       3 for user in response[0][0]:
#       4 #     print(user)
# ----> 5     keys = vars(user).keys()
#
# TypeError: vars() argument must have __dict__ attribute

# %%
user_id = 1061098849962471424
follow_url = f"https://api.twitter.com/2/users/{user_id}/following"

# %%
requests.get(follow_url, auth='L59QnUR4f69OSGhy1d9GaeKkC')

# %%
import requests
import os
import json

# To set your environment variables in your terminal run the following line:
# export 'BEARER_TOKEN'='<your_bearer_token>'
bearer_token = os.environ.get("BEARER_TOKEN")


def create_url():
    # Replace with user ID below
    user_id = 2244994945
    return "https://api.twitter.com/2/users/{}/followers".format(user_id)


def get_params():
    return {"user.fields": "created_at"}


def bearer_oauth(r):
    """
    Method required by bearer token authentication.
    """

    r.headers["Authorization"] = f"Bearer {bearer_token}"
    r.headers["User-Agent"] = "v2FollowersLookupPython"
    return r


def connect_to_endpoint(url, params):
    response = requests.request("GET", url, auth=bearer_oauth, params=params)
    print(response.status_code)
    if response.status_code != 200:
        raise Exception(
            "Request returned an error: {} {}".format(
                response.status_code, response.text
            )
        )
    return response.json()


def main():
    url = create_url()
    params = get_params()
    json_response = connect_to_endpoint(url, params)
    print(json.dumps(json_response, indent=4, sort_keys=True))
